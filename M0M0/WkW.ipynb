# %%
# -*- coding: utf-8 -*-
from lxml import html
from lxml import etree
from nltk import word_tokenize
import xml.etree.ElementTree  as ET 
def recuperationText(path):
    # Entree : string qui est le chemin vers nos données XML
    # Sortie : l'objet de la balise soit un texte
    # Objectif : recuper un texte XML et le transformer en texte de string
    
    #Etape 1 : l'extraction des balise textes
    tree = etree.parse(path) # c'est le dossier dans lequel on a du XML
    root = tree.getroot() # permet de recuperer la racine
    childrenRoot = root.getchildren()
    liste = []
    for rdc in childrenRoot:
        for etage in rdc:
            #print(elt1.getchildren())
            captureText = etage.findall("{http://www.mediawiki.org/xml/export-0.10/}text")# captureText est une liste
            for textBalise in captureText:
                liste.append(textBalise.text)
    
    # Etape 2 : transformer la liste de texte en super texte
    megaText = " ".join(liste)
    
    #Renvoie le texte
    return megaText
#return list of sentences
def purge(doc):
    
    result = "";
    flag = True;
    
    for mot in doc:
        
        #on enlève les contenues informatiques du style {%fbhjeiud} ou <ref></ref>
        if mot == '{' or mot == '<':
            flag = False;
        elif mot == '}' or mot == '>':
            flag = True;
        elif flag:
            
            if (mot not in ['\'','[',']','=','|','*']):
                result += mot;
            
            #on retire ensuite les ponctuations inutiles
            #if mot not in [ ';' , ':' , '\'']:
                
    
    #le texte est enfin "nettoyé"
    #print(result)
    sentences=result.split('\n')
    return sentences
pathFile = "essai.xml"
path = "WhoKilledWho/listSerialKiller.xml"
text = recuperationText(path)
sentences=purge(text)

# %%
import nltk
from semantic_tests import isALocation
from nltk import word_tokenize
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from nltk import pos_tag
def secondPurgeAndTokenize(list_of_sentences):
    tok_sentences=[]
    for s in list_of_sentences :
        #delete the empty lines and tokenize the sentences
        if len(s)>0:
            tok_sentences.append(nltk.word_tokenize(s))
    return tok_sentences
sentences=secondPurgeAndTokenize(sentences)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
def sortByCountries(list_tok_sentences):#takes a list of tokenized sentences and return a dictionnary with cases indexed by countries
    liste=[]
    index='none'
    dicti={}
    for t in list_tok_sentences:
        #we store murder cases in a temporary list
        #we make a semantic test to check if the expression is not a location (country, city...)
        #In our corpus murders are presented by countries, so if we find a new single counrty name (like 'The Bahamas')
        #it means we have now the murders in Bahamas, so we store our list of murder in the dictionnary, 
        #indexed with the country which came before and we empty the list
        if isALocation('_'.join(t)): 
            #if the country is already in the list
            if index in dicti:
                dicti[index].extend(liste)
            else:
                dicti[index]=liste
            liste=[]
            index=' '.join(t) 
        else:
             liste.append(t)
    #we delete the introduction of the corpus (everything written before the first country) 
    del dicti['none']
    return dicti
def postagAll(list_tok_sentences):#postag a list of tokenized sentences
    tagged_sentences=[]
    for t in list_tok_sentences:
        tagged_sentences.append(nltk.pos_tag(t))
    return tagged_sentences
cases= sortByCountries(sentences)
copy_dict={}
for country in cases :
    copy_dict[country]=postagAll(cases[country])
    
cases=copy_dict

# %%
#we are trying to tag Numbers which seems to be a year
def tagYEAR(tagged_sentence):
    copy=[]
    last_Prep=False#boolean to store if the word before the number is a Preposition or subordinating conjunction
    last_number=False #to store if we just found a number
    year=""
    for word in tagged_sentence:
        if last_Prep:#if we found a preposition then a number ther is a growing chance that this is a year
            if word[1]=="CD":
                last_number=True
                year= word[0]#we store the word
            elif last_number:
                if word[1]not in["NN","NNS","NNP","NNPS","JJ","JJS",'JJR']:# no noun or adjectives after to avoid expression like "in 12 cities"
                    copy.append((year,"YEAR"))#if there is no noun/adj after we tag it with "Year"
                    copy.append(word)
                else :#there is a noun/adj we tag it normally
                    last_number=False
                    last_Prep=False
                    copy.append((year,'CD'))
                    copy.append(word)            
            else: 
                last_Prep=False
                copy.append(word)
        elif word[1]in["IN",'TO']:
            last_Prep=True
            copy.append(word)
        else:
            copy.append(word)
    return copy

# %%
#We will try to handle issues with the preposition "of"
#so we creat a special tag for it
def tagOF(tagged_sentence):
    copy=[]
    for word in tagged_sentence:
        if word[0]in['de','of','von']:
            copy.append((word[0],'OF'))#creation of a special tag "OF" because there were a lot of issues in association 
            #like for exemple : (NP trial/NN)(CIRC for/IN (NP the/DT murders/NNS))(CIRC of/IN (NP five/CD elderly/JJ people/NNS)) "of five elderly peopleshould be associated with murder"
            #or Madame Truc de/von Machin                     
        else:
            copy.append(word)
    return copy

# %%
copy_dict3={}
for country in cases:
    temp_list=[]
    for sentence in cases[country]:
        sentence=tagOF(sentence)
        sentence=tagYEAR(sentence)
        temp_list.append(sentence)
    copy_dict3[country]=temp_list

# %%
cases=copy_dict3

# %%
#As we have some problem with nltk.ne_chunks() we will try to build our own Named Entities Recognizer
#Therefore we'll use Regexp
#We also used it to analyse the structure of the sentence

#From nltk.org
#We  consider Named-Entities as a sequence of proper nouns
#But we can consider that if the name is with a determiner, a noun or a foreign word it is part of the name Exemple : Jack the Ripper

def analyseSentence(sentence):
    pattern = r"""
        NE: {<NNP|NNPS>+}
        NE: {<DT|JJ|JJS><NNP|NNPS|NE>+}
        NE: {<NE|NNP|NNPS><OF><NE|NNP|NNPS>}

        NP: {<DT|PP\$|CD>?<JJ|JJS>*<NN|NNS>+} #chunk determiner/possessive, adjectives and noun
        NP: {<DT|PP\$|CD><NP>+}    
        NP: {<NP><CC><NP>}#Defined separately so that two NP already found and bound by a CC can be considered as one NP
        NP : {<NP><OF><NP>}
        NE: {<NE><NP>}        
        CIRC :{<IN><CD|NP|YEAR|NE>(<TO|CC><CD|NP|YEAR|NE>)*}#get the circumstance of the action
        
        VP:{<VBS|VBN|VBZ|VBG|VB|VBD>}
        VP:{<VP><CC><VP>}
        VP :{<VP><TO|OF>*<NP|NE>}
        VP : {<VP><CIRC>+}

    """
    cp = nltk.RegexpParser(pattern)
    return cp.parse(sentence)

#

#It would be interesting to detect the expression "also known as" to find the murderer nickname

# %%
copy_dict4={}
for country in cases:
    liste=[]
    for sentence in cases[country]:   
        liste.append(analyseSentence(sentence))
    copy_dict4[country]=liste

# %%
cases=copy_dict4

# %%
def getVerbPhrases(analysed_sentence):
    verb_phrase=[]
    last_label_VP=False#We will avoid having several time the same verbphrase because an other one is intricated on a bigger one
    for a in analysed_sentence.subtrees():
        if a.label()=="VP":
            if not last_label_VP:
                verb_phrase.append(a)
            last_label_VP=True
        else:
            last_label_VP=False

    return verb_phrase

# %%
from semantic_tests import isMurder,isALocation,isATimeIndicator
def getMurderInfo(analysed_sentence):#we will find and keep only the verb_phrases about the murders
    list_verb_phrases=getVerbPhrases(analysed_sentence)
    murders=[]#we can store several verb-phrases in case some criminal have been really...busy
    for a in list_verb_phrases:
        killed=False    #boolean storing if this verb phrase describe a murder
        if a.label()=="VP":
            for w in a.leaves():
                if isMurder(w[0]):
                    killed=True   
            if killed :
                murders.append(a)
    return murders
murders={}
for country in cases:
    liste=[]
    for sentence in cases[country]:
        liste.append(getMurderInfo(sentence))
    murders[country]=liste

# %%
def getCircumstances(analysed_sentence):
    circ=[]
    last_label_CIRC=False#We will avoid having several time the same verbphrase because an other one is intricated on a bigger one
    for a in analysed_sentence.subtrees():
        if a.label()=="CIRC":
            if not last_label_CIRC:
                circ.append(a.leaves())
            last_label_CIRC=True
        else:
            last_label_CIRC=False

    return circ
circ ={}
for country in murders:
    liste=[]
    for facts in murders[country]:
        for f in facts:
            liste.extend(getCircumstances(f))
    circ[country]=liste

# %%
def getPlaces(analysed_verbphrase):
    places=[]
    for a in analysed_verbphrase.subtrees():
        place_name=[]
        if a.label()=="CIRC":#we get all the circumstancial complement like 'In Ohahio','between 2001 and 2018'
            for s in a.subtrees():#We check the named entities
                if s.label()=="NE":
                    for w in s.leaves():
                        place_name.append(w[0])
                    if isALocation(' '.join(place_name)):#we found a location
                        place_name=[]
                        for word in a.leaves():
                            place_name.append(word[0])
                        places.append(' '.join(place_name))
                        
    return places  
places={}
for country in murders:
    liste=[]
    for facts in murders[country]:
        for f in facts:
            liste.append(getPlaces(f))
    places[country]=liste

# %%
def getTimes(analysed_verbphrase):
    times=[]
    for a in analysed_verbphrase.subtrees():
        time=False
        period=[]
        if a.label()=="CIRC":#we get all the circumstancial complement like 'In Ohahio','between 2001 and 2018'
            for w in a.leaves():
                if (isATimeIndicator(w[0])or w[1]=="YEAR")and w[1]!="IN" :#if there is a time indicator or a year tag
                    time=True#We also check that we are not analysing the semantic of a preposition becaus
                    
            if time:
                for w in a.leaves():
                    period.append(w[0])
                times.append(' '.join(period))   
    return times 
times={}
for country in murders:
    liste=[]
    for facts in murders[country]:
        for f in facts:
            liste.append(getTimes(f))
    times[country]=liste

# %%
def getNounPhrases(analysed_sentence):
    noun_phrase=[]
    last_label_NP=False#We will avoid having several time the same nounphrase because an other one is intricated on a bigger one
    for a in analysed_sentence.subtrees():
        if a.label()=="NP":
            if not last_label_NP:
                content=[]
                for w in a.leaves():
                    content.append(w[0])
                noun_phrase.append(content)
            last_label_NP=True
        else:
            last_label_NP=False

    return noun_phrase
def getObject(analysed_verbphrase):#we get all the noun phrases which are not in a circumstancial complement
    NP=getNounPhrases(analysed_verbphrase)#used to find the victim as the object of the action of killing
    verb_object=[]
    for a in analysed_verbphrase.subtrees():
        name=[]
        if a.label()in['CIRC'] :        
            for word in a.leaves():
                for n in NP:
                    found=False
                    if word[0] in n:
                        found=True
    for n in NP:
        verb_object.append(' '.join(n))
        
            
    return verb_object

# %%
victims={}
for country in murders:
    liste=[]
    for killer in murders[country]:
        for facts in killer:
            liste.append(getObject(facts))
    victims[country]=liste

# %%
print(victims['France'])
# Out:
# [['three women'], ['five women'], [], ['two people'], ['same year'], ['seven women and a man', '1976 night time or early morning'], [], ['seventeen men and boys'], [], ['the guillotine'], ['nine murders of young girls'], [], ['a life sentence', 'seven murders', '1997. websiteCrime'], [], ['a life sentence', 'twenty murders'], [], [], [], ['two men'], [], [], ['guillotine'], [], ['the murders'], ['two girlfriends'], [], ['the stake'], ['two husbands'], ['four people', '2012 motorcycle drive-bys'], [], [], ['63 would-be refugees'], [], [], ['an acquaintance'], [], [], [], ['three women'], ['three gay men'], [], ['a 1930 murder'], [], ['three people'], ['two double murders'], ['three people'], ['guillotine'], [], ['the strangulation murders of ten children'], ['American dancer'], ['a former accomplice']]

# %%
#In English the common way to write a sentence is Subject Verb Complement 
def getNE(analysed_sentence):
    named_entities=[]
    last_label_NE=False#We will avoid having several time the same verbphrase because an other one is intricated on a bigger one
    for a in analysed_sentence.subtrees():
        if a.label()=="NE":
            if not last_label_NE:
                name=[]
                for w in a.leaves():
                    name.append(w[0])
                named_entities.append(name)
            last_label_NE=True
        else:
            last_label_NE=False

    return named_entities

# %%
print(getNE(cases['France'][5]))
print(cases['France'][5])
# Out:
# [['Ludivine', 'Chambet'], ['The', 'Poisoner', 'of', 'Chambéry']]
# (S
#   (NE Ludivine/JJ (NE Chambet/NNP))
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE (NE The/DT (NE Poisoner/NNP)) of/OF (NE Chambéry/NNP))
#   ''/''
#   ;/:
#   (NP nurses/NNS)
#   aide/VBP
#   who/WP
#   (VP poisoned/VBD)
#   ten/RB
#   (NP elderly/JJ people/NNS)
#   (CIRC from/IN 2012/YEAR to/TO 2013/YEAR)
#   (VP (VP using/VBG) (NP 2013/CD antidepressants/NNS))
#   ;/:
#   (VP (VP sentenced/VBN) to/TO (NP 25/CD years/NNS imprisonment/NN))
#   ./.)

# %%
def getSubject(analysed_sentence):
    NE=getNE(analysed_sentence)
    subject=[]
    for a in analysed_sentence.subtrees():
        name=[]
        if a.label()in['CIRC','VP'] :        
            for word in a.leaves():
                for n in NE:
                    found=False
                    if word[0] in n:
                        found=True
            

    return NE

# %%
print(getSubject(cases['France'][5]))
# Out:
# [['Ludivine', 'Chambet'], ['The', 'Poisoner', 'of', 'Chambéry']]

# %%
boolean=True
for c in ['Chambet']:
    boolean= boolean and(c in['Ludivine', 'Chambet'])
boolean
# Out:
# True

# %%
copy_dict5={}
for country in cases:
    small_dict={}
    for murders in cases[country]:
        killer=getSubject(murders) #we choose the first named entity as the nameof our Murderer
        if(len(killer)>0):
            small_dict[' '.join(killer[0])]=murders
    copy_dict5[country]=small_dict

# %%
for country in copy_dict5:
    for killer in copy_dict5[country]:
        print(killer+':')
        print(copy_dict5[country][killer])
# Out:
# Abdullah Shah:
# (S
#   (NE Abdullah/NNP Shah/NNP)
#   :/:
#   (VP
#     (VP killed/VBN)
#     (CIRC at/IN (NP least/JJS twenty/JJ travelers/NNS))
#     (CIRC on/IN (NP the/DT road/NN))
#     (CIRC from/IN (NE Kabul/NNP) to/TO (NE Jalalabad/NNP)))
#   (VP (VP serving/VBG) (CIRC under/IN (NE Zardad/NNP Khan/NNP)))
#   ;/:
#   also/RB
#   (VP killed/VBD)
#   his/PRP$
#   (NP wife/NN)
#   ;/:
#   (VP (VP executed/VBN) (CIRC on/IN 20/CD))
#   (NE April/NNP)
#   2004/CD
#   ./.)
# John Baughman:
# (S
#   (NE John/NNP Baughman/NNP)
#   :/:
#   (NP former/JJ American/JJ police/NN officer/NN)
#   who/WP
#   (VP pushed/VBD)
#   his/PRP$
#   (NP second/JJ wife/NN)
#   (CIRC from/IN (NP the/DT roof/NN))
#   of/OF
#   (NE the/DT (NE Royal/NNP Antiguan/NNP Hotel/NNP))
#   (CIRC in/IN 1995/YEAR)
#   ;/:
#   1995/YEAR
#   (VP suspected/VBN)
#   1995/YEAR
#   of/OF
#   1995/YEAR
#   (VP killing/VBG)
#   1995/YEAR
#   (NP
#     (NP a/DT (NP 1995/CD close/JJ friend/NN))
#     and/CC
#     (NP first/JJ wife/NN))
#   back/RB
#   (CIRC in/IN (NE the/DT (NE USA/NNP)))
#   ;/:
#   (VP (VP (VP committed/VBD) (NP suicide/NN)) (CIRC in/IN 2000/YEAR))
#   ./.)
# Marcelo Antelo:
# (S
#   (NE Marcelo/NNP Antelo/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE The/DT (NE San/NNP La/NNP Muerte/NNP Killer/NNP))
#   ''/''
#   ;/:
#   (NP drug/NN addict/NN)
#   who/WP
#   (VP killed/VBD)
#   at/IN
#   least/JJS
#   (NP four/CD people/NNS)
#   (CIRC between/IN (NE February/NNP) and/CC (NE August/NNP))
#   2010/CD
#   ,/,
#   allegedly/RB
#   (CIRC
#     in/IN
#     (NP (NP the/DT name/NN) of/OF (NP a/DT pagan/JJ saint/NN)))
#   ;/:
#   (VP (VP sentenced/VBN) to/TO (NP life/NN imprisonment/NN))
#   ./.)
# Florencio Fernández:
# (S
#   (NE Florencio/NNP Fernández/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE The/DT (NE Argentine/NNP Vampire/NNP))
#   ''/''
#   ;/:
#   (VP (VP killed/VBN) (NP fifteen/JJ women/NNS))
#   in/IN
#   his/PRP$
#   (NP hometown/NN)
#   of/OF
#   (NE Monteros/NNP)
#   during/IN
#   the/DT
#   1950s/CD
#   ./.)
# Cayetano Santos Godino:
# (S
#   (NE Cayetano/NNP Santos/NNP Godino/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE Petiso/NNP Orejudo/NNP)
#   ''/''
#   (/(
#   ``/``
#   (NE Big/NNP Eared/NNP Midget/NNP)
#   ''/''
#   )/)
#   ;/:
#   (CIRC at/IN 16/YEAR)
#   ,/,
#   16/YEAR
#   (VP
#     (VP (VP killed/VBD) (NP four/CD children/NNS))
#     (CIRC in/IN 1912/YEAR))
#   ;/:
#   1912/YEAR
#   (VP died/VBN)
#   1912/YEAR
#   (CIRC in/IN (NP 1912/CD prison/NN))
#   (CIRC in/IN 1944/YEAR)
#   ./.)
# Cayetano Domingo Grossi:
# (S
#   (NE Cayetano/NNP Domingo/NNP Grossi/NNP)
#   :/:
#   (NP the/DT first/JJ serial/JJ killer/NN)
#   (CIRC in/IN (NE (NE Argentine/NNP) (NP history/NN)))
#   ;/:
#   (NP Italian/JJ immigrant/NN)
#   who/WP
#   (VP murdered/VBD)
#   five/CD
#   of/OF
#   his/PRP$
#   (NP newborn/JJ children/NNS)
#   (CIRC between/IN 1896/YEAR and/CC 1898/YEAR)
#   ;/:
#   1898/YEAR
#   (VP executed/VBN)
#   1900/YEAR
#   ./.)
# Francisco Antonio Laureana:
# (S
#   (NE Francisco/NNP Antonio/NNP Laureana/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE (NE The/DT (NE Satyr/NNP)) of/OF (NE San/NNP Isidro/NNP))
#   ,/,
#   (NE Buenos/NNP AiresSan/NNP Isidro/NNP)
#   ''/''
#   ;/:
#   (VP
#     (VP (VP murdered/VBD) (NP fifteen/JJ women/NNS))
#     (CIRC from/IN 1974/YEAR to/TO 1975/YEAR))
#   ,/,
#   1975/YEAR
#   (VP (VP raping/VBG) (NP 1975/CD thirteen/NN))
#   of/OF
#   them/PRP
#   ;/:
#   (VP
#     (VP killed/VBN)
#     (CIRC in/IN (NP a/DT shootout/NN))
#     (CIRC with/IN (NP the/DT police/NN))
#     (CIRC in/IN 1975/YEAR))
#   ./.)
# Yiya Murano:
# (S
#   (NE Yiya/JJ (NE Murano/NNP))
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE (NE The/DT (NE Poisoner/NNP)) of/OF (NE Monserrat/NNP))
#   ,/,
#   (NE Buenos/NNP AiresMonserrat/NNP)
#   ''/''
#   ,/,
#   (VP
#     (VP (VP poisoned/VBD) (NP three/CD women/NNS))
#     (CIRC in/IN (NE Buenos/NNP Aires/NNP))
#     (CIRC in/IN 1979/YEAR))
#   ./.)
# Robledo Puch:
# (S
#   (NE Robledo/NNP Puch/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE The/DT (NE Death/NNP Angel/NNP))
#   ''/''
#   and/CC
#   ``/``
#   (NE The/DT (NE Black/NNP Angel/NNP))
#   ''/''
#   ;/:
#   (VP killed/VBN)
#   eleven/RB
#   (NP people/NNS)
#   before/IN
#   his/PRP$
#   (NP arrest/NN)
#   (CIRC in/IN 1972/YEAR)
#   ;/:
#   1972/YEAR
#   (VP sentenced/VBN)
#   1972/YEAR
#   to/TO
#   (NP 1972/CD life/NN imprisonment/NN)
#   (CIRC in/IN 1980/YEAR)
#   ./.)
# John Balaban:
# (S
#   (NE John/NNP Balaban/NNP)
#   (/(
#   (NP serial/JJ killer/NN)
#   )/)
#   (NE John/NNP Balaban/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE Romanian/JJ (NE Maniac/NNP))
#   ''/''
#   ;/:
#   (NP Romanian/JJ emigrant/NN)
#   who/WP
#   (VP murdered/VBD)
#   at/IN
#   least/JJS
#   (NP five/CD people/NNS)
#   (CIRC in/IN (NE France/NNP) and/CC (NE Australia/NNP))
#   (CIRC from/IN 1948/YEAR to/TO 1953/YEAR)
#   ,/,
#   1953/YEAR
#   (VP including/VBG)
#   1953/YEAR
#   his/PRP$
#   (NP 1953/CD wife/NN)
#   and/CC
#   her/PRP$
#   (NP family/NN)
#   ;/:
#   (VP executed/VBN)
#   1953/CD
#   ./.)
# David:
# (S
#   (NE David/NNP)
#   and/CC
#   (NE Catherine/NNP Birnie/NNP)
#   :/:
#   responsible/JJ
#   for/IN
#   the/DT
#   ``/``
#   (NE Moorhouse/NNP Murders/NNP)
#   ''/''
#   ;/:
#   (NP couple/NN)
#   (CIRC from/IN (NE (NE the/DT (NE Perth/NNP)) (NP suburb/NN)))
#   of/OF
#   (NE Willagee/NNP)
#   ,/,
#   (NE Western/NNP AustraliaWillagee/NNP)
#   who/WP
#   (VP
#     (VP
#       (VP (VP raped/VBD) and/CC (VP murdered/VBD))
#       (NP four/CD women/NNS))
#     (CIRC in/IN 1986/YEAR))
#   ./.)
# Gregory Brazel:
# (S
#   (NE Gregory/NNP Brazel/NNP)
#   :/:
#   (NE Victoria/NNP)
#   (/(
#   (NE Australia/NNP)
#   )/)
#   (NE (NE Victoria/NNP) (NP man/NN))
#   who/WP
#   (VP (VP shot/VBZ) (NP a/DT woman/NN))
#   to/TO
#   (NP death/NN)
#   (CIRC in/IN (NP a/DT (NP 1982/CD armed/JJ robbery/NN)))
#   ,/,
#   and/CC
#   (VP
#     (VP (VP murdered/VBD) (NP two/CD prostitutes/NNS))
#     (CIRC in/IN 1990/YEAR))
#   ./.)
# John Bunting:
# (S
#   (NE John/NNP Bunting/NNP)
#   (/(
#   (NP serial/JJ killer/NN)
#   )/)
#   (NE John/NNP Bunting/NNP)
#   ,/,
#   (NE Robert/NNP Wagner/NNP)
#   (/(
#   (NP serial/JJ killer/NN)
#   )/)
#   (NE Robert/NNP Wagner/NNP)
#   and/CC
#   (NE James/NNP Vlassakis/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NP Bodies/NNS)
#   (CIRC in/IN (NE the/DT (NE Barrels/NNP Murders/NNP)))
#   ''/''
#   ;/:
#   (VP
#     (VP
#       (VP convicted/VBN)
#       of/OF
#       (NE
#         (NE the/DT (NE Snowtown/NNP))
#         (NP (NP murders/NNS) of/OF (NP twelve/NN people/NNS))))
#     (CIRC between/IN 1992/YEAR and/CC 1999/YEAR))
#   ./.)
# Robert Francis Burns:
# (S
#   (NE Robert/NNP Francis/NNP Burns/NNP)
#   :/:
#   (VP (VP confessed/VBN) to/TO (NP eight/CD killings/NNS))
#   ;/:
#   (VP (VP hanged/VBN) (CIRC in/IN (NE Ararat/NNP)))
#   ,/,
#   (NE VictoriaArarat/NNP)
#   (CIRC in/IN 1883/YEAR)
#   ./.)
# Clarke brothersThomas:
# (S
#   (NE (NE Clarke/NNP) (NP brothersThomas/NN))
#   and/CC
#   (NE John/NNP Clarke/NNP)
#   :/:
#   (NP bushranger/NN brothers/NNS)
#   who/WP
#   (VP (VP robbed/VBD) (NP railroad/NN stations/NNS))
#   ;/:
#   (VP (VP killed/VBN) (NP five/CD police/NNS officers/NNS))
#   ;/:
#   (NE the/DT (NE Felons/NNP Apprehension/NNP Act/NNP))
#   of/OF
#   1886/CD
#   ,/,
#   which/WDT
#   (VP (VP allowed/VBD) (NP bushrangers/NNS))
#   to/TO
#   (VP be/VB)
#   (VP (VP killed/VBN) (CIRC on/IN (NP sight/NN)))
#   ,/,
#   (VP was/VBD)
#   (VP created/VBN)
#   because/IN
#   of/OF
#   them/PRP
#   ;/:
#   both/DT
#   (VP hanged/VBD)
#   1867/CD
#   ./.)
# Eric Edgar Cooke:
# (S
#   (NE Eric/NNP Edgar/NNP Cooke/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE Night/NNP Caller/NNP)
#   ''/''
#   ;/:
#   (VP killed/VBN)
#   at/IN
#   least/JJS
#   (NP eight/CD people/NNS)
#   and/CC
#   (VP attempted/VBN)
#   to/TO
#   (VP kill/VB)
#   many/JJ
#   more/JJR
#   in/IN
#   and/CC
#   (CIRC around/IN (NE Perth/NNP))
#   (CIRC between/IN 1959/YEAR and/CC 1963/YEAR)
#   ;/:
#   (NP 1963/CD last/JJ person/NN)
#   to/TO
#   (VP be/VB)
#   (VP
#     (VP hanged/VBN)
#     (CIRC in/IN (NE Western/JJ (NE Australia/NNP))))
#   ./.)
# John Leslie Coombes:
# (S
#   (NE John/NNP Leslie/NNP Coombes/NNP)
#   :/:
#   (VP
#     (VP (VP killed/VBN) (NP two/CD men/NNS))
#     (CIRC in/IN 1984/YEAR and/CC (NP one/CD woman/NN))
#     (CIRC in/IN 2009/YEAR)
#     (CIRC around/IN 2009/YEAR))
#   the/DT
#   2009/CD
#   (NE (NE Victoria/NNP) (NP area/NN))
#   ./.)
# Bandali Debs:
# (S
#   (NE Bandali/NNP Debs/NNP)
#   :/:
#   (VP convicted/VBN)
#   of/OF
#   (VP
#     (VP murdering/VBG)
#     (NP
#       (NP two/CD police/NN officers/NNS)
#       and/CC
#       (NP two/CD prostitutes/NNS)))
#   in/IN
#   the/DT
#   1990s/CD
#   ./.)
# Paul Denyer:
# (S
#   (NE Paul/NNP Denyer/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE Frankston/NNP Killer/NNP)
#   ''/''
#   ;/:
#   (VP
#     (VP (VP murdered/VBD) (NP three/CD women/NNS))
#     (CIRC in/IN 1993/YEAR)
#     (CIRC in/IN 1993/YEAR))
#   the/DT
#   1993/CD
#   (NE (NE Melbourne/NNP) (NP suburb/NN))
#   of/OF
#   (NE Frankston/NNP)
#   ,/,
#   (NE VictoriaFrankston/NNP)
#   ./.)
# Peter Dupas:
# (S
#   (NE Peter/NNP Dupas/NNP)
#   :/:
#   (NP serving/NN)
#   (NP three/CD life/NN sentences/NNS)
#   (CIRC
#     for/IN
#     (NP (NP multiple/JJ murder/NN) and/CC (NP rape/NN charges/NNS)))
#   (CIRC in/IN (NE Victoria/NNP))
#   ./.
#   (NP date13/NN)
#   (NE (NE August/NNP) (NP 2004/CD newspaperThe/NN))
#   (NE Age/NNP)
#   (VP
#     (VP locationMelbourne/VBZ)
#     (NE access-date24/JJ (NE November/NNP)))
#   2019/CD)
# Kathleen Folbigg:
# (S
#   (NE Kathleen/NNP Folbigg/NNP)
#   :/:
#   (VP murdered/VBD)
#   four/CD
#   of/OF
#   her/PRP$
#   (NP infants/NNS)
#   (CIRC between/IN 1991/YEAR and/CC 1999/YEAR)
#   ./.)
# Leonard Fraser:
# (S
#   (NE Leonard/NNP Fraser/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE Rockhampton/NNP Rapist/NNP)
#   ''/''
#   ;/:
#   (VP convicted/VBN)
#   of/OF
#   (VP
#     (VP (VP killing/VBG) (NP four/CD women/NNS))
#     (CIRC in/IN (NE Rockhampton/NNP)))
#   ,/,
#   (NE Queensland/NNP)
#   ./.)
# John Wayne Glover:
# (S
#   (NE John/NNP Wayne/NNP Glover/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE Granny/NNP Killer/NNP)
#   ''/''
#   ;/:
#   (VP
#     (VP (VP killed/VBN) (NP six/CD elderly/JJ women/NNS))
#     (CIRC on/IN (NE Sydneys/NNP North/NNP Shore/NNP)))
#   (/(
#   (NE Sydney/NNP)
#   )/)
#   (NE North/NNP Shore/NNP)
#   ;/:
#   (VP (VP (VP committed/VBD) (NP suicide/NN)) (CIRC in/IN 2005/YEAR))
#   ./.)
# Caroline Grills:
# (S
#   (NE Caroline/NNP Grills/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE Auntie/NNP Thally/NNP)
#   ''/''
#   ;/:
#   a/DT
#   (NE serial/JJ (NE Poison/NNP))
#   #/#
#   (NE Uses/NNP)
#   of/OF
#   (NP
#     (NP poisonpoisoner/NN)
#     of/OF
#     (NP five/CD family/NN members/NNS))
#   (CIRC in/IN (NE New/NNP South/NNP Wales/NNP))
#   (CIRC between/IN 1947/YEAR and/CC 1953/YEAR)
#   ./.)
# Paul Steven Haigh:
# (S
#   (NE Paul/NNP Steven/NNP Haigh/NNP)
#   :/:
#   (VP
#     (VP (VP sentenced/VBN) to/TO (NP life/NN imprisonment/NN))
#     (CIRC without/IN (NP parole/NN))
#     (CIRC
#       for/IN
#       (NP (NP the/DT murders/NNS) of/OF (NP seven/CD people/NNS)))
#     (CIRC in/IN (NE Victoria/NNP))
#     (CIRC in/IN (NP the/DT late/JJ 1970s/NNS)))
#   ./.)
# Matthew James Harris:
# (S
#   (NE Matthew/NNP James/NNP Harris/NNP)
#   :/:
#   (VP (VP strangled/VBD) (NP a/DT friends/NNS brother/NN))
#   ,/,
#   (NP a/DT female/JJ friend/NN)
#   ,/,
#   and/CC
#   (NP a/DT male/JJ neighbor/NN)
#   to/TO
#   (NP death/NN)
#   (CIRC over/IN (NP five/CD weeks/NNS))
#   (CIRC in/IN 1998/YEAR)
#   (CIRC in/IN 1998/CD)
#   (NE Wagga/NNP Wagga/NNP)
#   ./.)
# Thomas Jeffries:
# (S
#   (NE (NE Thomas/NNP) (NP Jeffries/NNS))
#   :/:
#   (NP Tasmanian/JJ penal/JJ colony/NN escapee/NN)
#   responsible/JJ
#   (CIRC
#     for/IN
#     (NP (NP the/DT murders/NNS) of/OF (NP five/CD people/NNS)))
#   ;/:
#   (VP
#     (VP executed/VBN)
#     (CIRC in/IN (NP 1826.Thomas/CD Jeffries/NNS)))
#   convict/VBP
#   No/DT
#   ./.
#   3634/CD
#   ,/,
#   (NP conduct/NN record/NN)
#   ,/,
#   (NE (NE State/NNP Archives/NNPS) of/OF (NE Tasmania/NNP))
#   ./.)
# Knorr:
# (S
#   (NP Frances/NNS)
#   (NE Knorr/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE Baby/NNP Farming/NNP Murderess/NNP)
#   ''/''
#   ;/:
#   (NE (NE English-born/NNP) (NP baby/NN farmer/NN))
#   who/WP
#   (VP (VP killed/VBD) (NP three/CD infants/NNS))
#   ;/:
#   (VP executed/VBN)
#   1894/CD
#   ./.)
# Eddie Leonski:
# (S
#   (NE Eddie/NNP Leonski/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE Brownout/NNP Strangler/NNP)
#   ''/''
#   ;/:
#   (NE (NE United/NNP States/NNPS Army/NNP) (NP soldier/NN))
#   who/WP
#   (VP
#     (VP (VP killed/VBD) (NP three/CD women/NNS))
#     (CIRC in/IN (NE Melbourne/NNP)))
#   ;/:
#   (VP (VP executed/VBN) (CIRC in/IN 1942/YEAR))
#   ./.)
# John Lynch:
# (S
#   (NE John/NNP Lynch/NNP)
#   (/(
#   (NP serial/JJ killer/NN)
#   )/)
#   (NE John/NNP Lynch/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE Berrima/NNP)
#   ,/,
#   (NE New/NNP South/NNP WalesBerrima/NNP Axe/NNP Murderer/NNP)
#   ''/''
#   ;/:
#   (VP killed/VBN)
#   ten/VBP
#   (NP people/NNS)
#   (CIRC from/IN 1835/YEAR to/TO 1841/YEAR)
#   ./.)
# William MacDonald:
# (S
#   (NE William/NNP MacDonald/NNP)
#   (/(
#   (NP serial/JJ killer/NN)
#   )/)
#   (NE William/NNP MacDonald/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE Mutilator/NNP)
#   ''/''
#   ;/:
#   (NE (NE English/NNP) (NP immigrant/NN))
#   who/WP
#   (VP killed/VBD)
#   at/IN
#   least/JJS
#   (NP five/CD men/NNS)
#   (CIRC between/IN (NE June/NNP))
#   1961/CD
#   and/CC
#   (NE April/NNP)
#   1963/CD
#   (CIRC throughout/IN (NE Sydney/NNP))
#   ./.)
# John:
# (S
#   (NE John/NNP)
#   ``/``
#   (NE Rocky/NNP)
#   ''/''
#   (NP Whelan/NN)
#   :/:
#   (NP Tasmanian/JJ penal/JJ colony/NN escapee/NN)
#   responsible/JJ
#   (CIRC
#     for/IN
#     (NP (NP the/DT murders/NNS) of/OF (NP five/CD people/NNS)))
#   ;/:
#   (VP (VP executed/VBN) (CIRC in/IN 1855/YEAR))
#   ./.)
# Malachi Martin:
# (S
#   (NE Malachi/NNP Martin/NNP)
#   (/(
#   (NP murderer/NN)
#   )/)
#   (NE Malachi/NNP Martin/NNP)
#   :/:
#   (VP convicted/VBN)
#   of/OF
#   (VP (VP killing/VBG) (NE Jane/NNP Macmanamin/NNP))
#   and/CC
#   (VP suspected/VBN)
#   of/OF
#   (VP (VP murdering/VBG) (NP four/CD additional/JJ people/NNS))
#   as/RB
#   well/RB
#   as/IN
#   (VP being/VBG)
#   (VP
#     (VP implicated/VBN)
#     (CIRC in/IN (NP the/DT suspicious/JJ death/NN)))
#   of/OF
#   his/PRP$
#   (NP mother/NN)
#   ;/:
#   (VP
#     (VP hanged/VBN)
#     (CIRC at/IN (NE the/DT (NE Adelaide/NNP Gaol/NNP)))
#     (CIRC in/IN (NP 1862.Martins/CD marriage/NN certificate/NN)))
#   (VP (VP shows/VBZ) (NP this/DT spelling/NN))
#   ,/,
#   while/IN
#   (CIRC on/IN (NP that/DT certificate/NN))
#   he/PRP
#   (VP signed/VBD)
#   his/PRP$
#   (NP name/NN)
#   ``/``
#   (NE Malacky/NNP)
#   ''/''
#   (/(
#   (NP 1858/CD marriage/NN certificate/NN)
#   (VP (VP indexed/VBN) (CIRC by/IN (NE Births/NNP)))
#   ,/,
#   (NE Deaths/NNP)
#   and/CC
#   (NE Marriages/NNP South/NNP Australia/NNP)
#   (CIRC at/IN (NE Book/NNP))
#   317/CD
#   ,/,
#   (NE Page/NNP)
#   541/CD
#   )/)
#   ./.
#   On/IN
#   his/PRP$
#   (NP petition/NN)
#   to/TO
#   (NE the/DT (NE Governor/NNP))
#   (CIRC in/IN (NE December/NNP))
#   1862/CD
#   (NE Martin/NNP)
#   (VP signed/VBD)
#   his/PRP$
#   (NP name/NN)
#   ``/``
#   (NE Malaky/NNP Martin/NNP)
#   ''/''
#   (/(
#   (NE (NE Malachy/NNP Martins/NNP) (NP petition/NN))
#   to/TO
#   (NE the/DT (NE Governor/NNP))
#   &/CC
#   (NE
#     (NE Executive/NNP Council/NNP)
#     of/OF
#     (NE South/NNP Australia/NNP))
#   ,/,
#   (NE GRG/NNP)
#   24/6/1862/1215/CD
#   )/)
#   ./.
#   (CIRC In/IN (NP oral/JJ tradition/NN))
#   (NP the/DT name/NN)
#   (VP is/VBZ)
#   (VP (VP pronounced/VBN) (CIRC in/IN (NP a/DT way/NN)))
#   that/WDT
#   (VP indicates/VBZ)
#   it/PRP
#   should/MD
#   (VP be/VB)
#   (VP spelt/VBN)
#   ``/``
#   (NE Malachy/NNP)
#   ''/''
#   rather/RB
#   (CIRC than/IN (NE the/DT (NE Biblical/NNP)))
#   ``/``
#   (NE Malachi/NNP)
#   ''/''
#   ./.
#   (NE John/NNP Bowyer/NNP Bull/NNP)
#   ,/,
#   who/WP
#   (VP had/VBD)
#   (VP (VP met/VBN) (NE Malachy/NNP))
#   ,/,
#   (VP mentions/VBZ)
#   him/PRP
#   in/IN
#   his/PRP$
#   (NP memoirs/NN)
#   ,/,
#   and/CC
#   although/IN
#   he/PRP
#   (VP (VP spells/VBZ) (NP the/DT name/NN))
#   (NP several/JJ ways/NNS)
#   ,/,
#   they/PRP
#   are/VBP
#   all/DT
#   closer/JJR
#   to/TO
#   ``/``
#   (NE Malachy/NNP)
#   ''/''
#   than/IN
#   to/TO
#   ``/``
#   (NE Malachi/NNP)
#   ''/''
#   (/(
#   (NE J.B./NNP Bull/NNP)
#   ,/,
#   (NP unpublished/JJ manuscript/NN)
#   (NE
#     (NE The/DT (NE Life/NNP))
#     of/OF
#     (NE John/NNP Bowyer/NNP Bull/NNP))
#   ,/,
#   (NE The/DT (NE Australian/NNP Bushman/NNP))
#   &/CC
#   (NE Explorer/NNP)
#   ,/,
#   (NP 1838/CD –1894/NN)
#   ,/,
#   (NE PGR/NNP)
#   507/3/CD
#   ,/,
#   pp/RB
#   62-65/JJ
#   )/)
#   ./.)
# Backpacker MurdersIvan Milat:
# (S
#   (NE Backpacker/NNP MurdersIvan/NNP Milat/NNP)
#   :/:
#   (VP killed/VBN)
#   at/IN
#   least/JJS
#   (NP seven/CD tourists/NNS)
#   (CIRC in/IN (NE Belanglo/NNP State/NNP Forest/NNP))
#   ,/,
#   (NE New/NNP South/NNP Wales/NNP)
#   (CIRC between/IN 1989/YEAR and/CC 1993/YEAR)
#   ,/,
#   1993/YEAR
#   which/WDT
#   1993/YEAR
#   (VP became/VBD)
#   1993/YEAR
#   (VP known/VBN)
#   1993/YEAR
#   (CIRC as/IN 1993/YEAR)
#   the/DT
#   1993/YEAR
#   ``/``
#   1993/CD
#   (NE Backpacker/NNP Murders/NNP)
#   ''/''
#   ;/:
#   (VP
#     (VP suspected/VBN)
#     (CIRC in/IN (NP similar/JJ disappearances/NNS))
#     (CIRC in/IN (NE (NE City/NNP) of/OF (NE NewcastleNewcastle/NNP))))
#   ./.)
# Dan Morgan:
# (S
#   (NE Dan/NNP Morgan/NNP)
#   (/(
#   (NP bushranger/NN)
#   )/)
#   (NE Dan/NNP Morgan/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE Mad/NNP Dog/NNP)
#   ''/''
#   ;/:
#   (NP violent/JJ bushranger/NN)
#   who/WP
#   (VP
#     (VP (VP killed/VBD) (NP three/CD people/NNS))
#     (CIRC from/IN 1864/YEAR to/TO 1865/YEAR))
#   ;/:
#   1865/YEAR
#   (VP killed/VBN)
#   1865/YEAR
#   (CIRC during/IN 1865/YEAR)
#   (NP a/DT (NP 1865/CD standoff/NN))
#   (CIRC with/IN (NE (NE the/DT (NE Victoria/NNP)) (NP police/NNS)))
#   ./.)
# Martha Needle:
# (S
#   (NE Martha/NNP Needle/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE (NE Black/NNP Widow/NNP) of/OF (NE Richmond/NNP))
#   ,/,
#   (NE VictoriaRichmond/NNP)
#   ,/,
#   ''/''
#   (NE Poison/NNP)
#   #/#
#   (NE Uses/NNP)
#   of/OF
#   (NP
#     (NP poisonpoisoner/NN)
#     of/OF
#     (NP four/CD family/NN members/NNS))
#   and/CC
#   her/PRP$
#   (NP boyfriends/NNS brother/NN)
#   ;/:
#   (VP (VP executed/VBN) (CIRC in/IN 1894/YEAR))
#   ./.)
# Alexander Pearce:
# (S
#   (NE Alexander/NNP Pearce/NNP)
#   :/:
#   (NP Irish/JJ convict/NN)
#   who/WP
#   (VP
#     (VP escaped/VBD)
#     (CIRC with/IN (NP seven/CD other/JJ convicts/NNS))
#     (CIRC from/IN (NP imprisonment/NN)))
#   ;/:
#   five/CD
#   of/OF
#   them/PRP
#   (VP were/VBD)
#   (VP (VP killed/VBN) and/CC (VP cannibalised/VBN))
#   ,/,
#   (VP (VP leaving/VBG) (NE Pearce/NNP))
#   the/DT
#   only/RB
#   (NP one/NN)
#   (VP left/VBD)
#   ;/:
#   (VP hanged/VBN)
#   1824/CD
#   ./.)
# Derek Percy:
# (S
#   (NE Derek/NNP Percy/NNP)
#   :/:
#   (VP
#     (VP (VP murdered/VBD) (NP a/DT child/NN))
#     (CIRC in/IN 1969/YEAR))
#   ,/,
#   1969/YEAR
#   but/CC
#   1969/YEAR
#   also/RB
#   1969/YEAR
#   (VP linked/VBD)
#   1969/YEAR
#   to/TO
#   1969/YEAR
#   (NP
#     (NP the/DT (NP 1969/CD deaths/NNS))
#     of/OF
#     (NP eight/CD other/JJ children/NNS))
#   in/IN
#   the/DT
#   60s/CD
#   ;/:
#   (VP
#     (VP died/VBN)
#     (CIRC in/IN (NP prison/NN))
#     (CIRC from/IN (NP lung/NN cancer/NN)))
#   ./.)
# Martha Rendell:
# (S
#   (NE Martha/NNP Rendell/NNP)
#   :/:
#   (VP
#     (VP (VP killed/VBD) (NP three/CD stepchildren/NN))
#     (CIRC with/IN (NP hydrochloric/JJ acid/NN))
#     (CIRC in/IN 1907-08/YEAR))
#   ;/:
#   (NP 1907-08/CD last/JJ woman/NN)
#   to/TO
#   (VP be/VB)
#   (VP
#     (VP hanged/VBN)
#     (CIRC in/IN (NE Western/JJ (NE Australia/NNP))))
#   ./.)
# Lindsey Robert Rose:
# (S
#   (NE Lindsey/NNP Robert/NNP Rose/NNP)
#   :/:
#   (NE
#     (NE New/NNP South/NNP Wales/NNP)
#     (NP (NP serial/NN) and/CC (NP contract/NN killer/NN)))
#   who/WP
#   (VP
#     (VP (VP murdered/VBD) (NP five/CD people/NNS))
#     (CIRC between/IN 1984/YEAR and/CC 1994/YEAR))
#   ./.)
# Murchison MurdersSnowy Rowles:
# (S
#   (NE Murchison/NNP MurdersSnowy/NNP Rowles/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE Murchison/NNP)
#   (/(
#   (NE Western/NNP Australia/NNP)
#   )/)
#   (NE Murchison/NNP Murders/NNP)
#   ''/''
#   ;/:
#   (NP stockman/NN)
#   who/WP
#   (VP (VP murdered/VBD) (NP three/CD people/NNS))
#   (VP (VP using/VBG) (NP a/DT method/NN))
#   from/IN
#   a/DT
#   then/RB
#   (NP (NP unpublished/JJ book/NN) of/OF (NP author/NN))
#   (NE Arthur/NNP Upfield/NNP)
#   ./.)
# Albert Schmidt:
# (S
#   (NE Albert/NNP Schmidt/NNP)
#   (/(
#   (NP serial/JJ killer/NN)
#   )/)
#   (NE Albert/NNP Schmidt/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE The/DT (NE Wagga/NNP Murderer/NNP))
#   ''/''
#   ;/:
#   (NP German/JJ immigrant/NN)
#   who/WP
#   (VP murdered/VBD)
#   at/IN
#   least/JJS
#   three/CD
#   (VP
#     (VP (VP travelling/VBG) (NP companions/NNS))
#     (CIRC from/IN 1888/YEAR to/TO 1890/YEAR))
#   ;/:
#   1890/YEAR
#   (VP executed/VBN)
#   1890/YEAR
#   (CIRC for/IN (NP one/CD murder/NN))
#   (CIRC in/IN 1890/YEAR)
#   ./.)
# Arnold Sodeman:
# (S
#   (NE Arnold/NNP Sodeman/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE School-girl/JJ (NE Strangler/NNP))
#   ''/''
#   ;/:
#   (VP
#     (VP (VP killed/VBN) (NP four/CD children/NNS))
#     (CIRC in/IN (NE Melbourne/NNP)))
#   in/IN
#   the/DT
#   1930s/CD
#   ./.)
# Truro:
# (S
#   (NE Truro/NNP)
#   murdersChristopher/CC
#   (NE Worrell/NNP)
#   and/CC
#   (NE James/NNP Miller/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE Truro/NNP)
#   ,/,
#   (NE South/NNP AustraliaTruro/NNP Murderers/NNP)
#   ''/''
#   ;/:
#   (VP were/VBD)
#   (VP convicted/VBN)
#   of/OF
#   (VP
#     (VP (VP killing/VBG) (NP seven/CD people/NNS))
#     (CIRC in/IN 1976–1977/YEAR))
#   ./.)
# Bowraville Murders:
# (S
#   (NE (NE Bowraville/NNP) (NP Murders/NNS))
#   :/:
#   (NP murders/NNS)
#   of/OF
#   three/CD
#   (NE
#     (NE Indigenous/NNP AustraliansAboriginal/NNP)
#     (NP children/NNS))
#   (CIRC in/IN 1990/YEAR and/CC 1991./CD)
#   dateFebruary/JJ
#   8/CD
#   ,/,
#   2004/CD
#   (NE newspaperThe/JJ (NE Sydney/NNP Morning/NNP Herald/NNP))
#   (NE access-date24/JJ (NE November/NNP))
#   2019/CD)
# Claremont serial killings:
# (S
#   (NE (NE Claremont/NNP) (NP serial/JJ killings/NNS))
#   :/:
#   (NP
#     (NP murders/NNS)
#     of/OF
#     (NP
#       (NP two/CD young/JJ women/NNS)
#       and/CC
#       (NP the/DT disappearance/NN)))
#   of/OF
#   a/DT
#   third/JJ
#   (CIRC in/IN 1996/YEAR and/CC 1997/YEAR)
#   ./.)
# The Family Murders:
# (S
#   (NE (NE The/DT (NE Family/NNP)) (NP Murders/NNS))
#   :/:
#   (NP
#     (NP (NP murder/NN) and/CC (NP mutilation/NN))
#     of/OF
#     (NP (NP five/CD young/JJ men/NNS) and/CC (NP boys/NNS)))
#   (CIRC from/IN 1979/YEAR to/TO 1983/YEAR)
#   ./.
#   1983/CD
#   (NE (NE Bevan/NNP Spencer/NNP) von/OF (NE Einem/NNP))
#   (VP was/VBD)
#   (VP (VP convicted/VBN) of/OF (NP one/CD murder/NN))
#   ./.)
# Tynong North:
# (S
#   (NE Tynong/NNP North/NNP)
#   and/CC
#   (NE Frankston/NNP Murders/NNP)
#   :/:
#   (NP (NP murders/NNS) of/OF (NP six/CD females/NNS))
#   (CIRC in/IN (NE Tynong/NNP North/NNP))
#   ,/,
#   (NE VictoriaTynong/NNP North/NNP)
#   and/CC
#   (NE Frankston/NNP)
#   (CIRC in/IN 1980/YEAR and/CC 1981/YEAR)
#   ./.)
# Elfriede Blauensteiner:
# (S
#   (NE Elfriede/NNP Blauensteiner/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE Black/NNP Widow/NNP)
#   ''/''
#   ;/:
#   (NP (NP poisoner/NN) of/OF (NP three/CD individuals/NNS))
#   ;/:
#   (VP
#     (VP died/VBN)
#     (CIRC in/IN (NP prison/NN))
#     (CIRC in/IN 2003/YEAR))
#   ./.)
# Max Gufler:
# (S
#   (NE Max/NNP Gufler/NNP)
#   :/:
#   (VP (VP (VP poisoned/VBN) and/CC (VP drowned/VBN)) (NP women/NNS))
#   ;/:
#   (VP
#     (VP convicted/VBN)
#     of/OF
#     (NP
#       (NP four/CD murders/NNS)
#       and/CC
#       (NP two/CD attempted/JJ murders/NNS)))
#   ,/,
#   but/CC
#   (VP believed/VBD)
#   to/TO
#   (VP have/VB)
#   (VP committed/VBN)
#   18/CD
#   ;/:
#   (VP died/VBD)
#   1996/CD
#   ./.)
# Dariusz Kotwica:
# (S
#   (NE Dariusz/NNP Kotwica/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE Euro/NNP Ripper/NNP)
#   ''/''
#   ;/:
#   (NE (NE Polish/NNP) (NP vagrant/NN))
#   who/WP
#   (VP murdered/VBD)
#   at/IN
#   least/JJS
#   (NP three/CD pensioners/NNS)
#   (CIRC in/IN (NE Austria/NNP) and/CC (NE Sweden/NNP))
#   (CIRC in/IN 2015/YEAR)
#   ;/:
#   2015/YEAR
#   (VP suspected/VBN)
#   2015/YEAR
#   of/OF
#   2015/CD
#   more/JJR
#   (NP murders/NNS)
#   (CIRC in/IN (NE the/DT (NE Netherlands/NNP)))
#   ,/,
#   (NE Czech/NNP Republic/NNP)
#   and/CC
#   (NE the/DT (NE United/NNP Kingdom/NNP))
#   ;/:
#   (VP (VP sentenced/VBN) to/TO (NP involuntary/JJ commitment/NN))
#   ./.)
# Martha Marek:
# (S
#   (NE Martha/NNP Marek/NNP)
#   :/:
#   (VP
#     (VP poisoned/VBD)
#     (NP
#       (NP three/CD family/NN members/NNS)
#       and/CC
#       (NP a/DT lodger/NN)))
#   in/IN
#   her/PRP$
#   (NP house/NN)
#   (CIRC with/IN (NP thallium/NN))
#   (CIRC between/IN 1932/YEAR and/CC 1937/YEAR)
#   ;/:
#   1937/YEAR
#   (VP executed/VBN)
#   1938/YEAR
#   ./.)
# Wolfgang Ott:
# (S
#   (NE Wolfgang/NNP Ott/NNP)
#   :/:
#   (NP sex/NN offender/NN)
#   and/CC
#   (VP (VP suspected/VBD) (NP serial/JJ killer/NN))
#   who/WP
#   (VP
#     (VP (VP kidnapped/VBD) (NP several/JJ women/NNS))
#     (CIRC in/IN 1995/YEAR))
#   ,/,
#   1995/YEAR
#   (VP killing/VBG)
#   two/YEAR
#   of/OF
#   two/YEAR
#   them/PRP
#   two/YEAR
#   ;/:
#   two/YEAR
#   (VP sentenced/VBN)
#   two/YEAR
#   to/TO
#   (NP two/CD life/NN imprisonment/NN)
#   (CIRC in/IN (NP 1996./CD date2017-04-27/JJ websiteORF/NN))
#   (/(
#   (NP broadcaster/NN)
#   )/)
#   (NE ORF/NNP)
#   languagede/VBP
#   (NP access-date2018-01-29/NN))
# Harald Sassak:
# (S
#   (NE Harald/NNP Sassak/NNP)
#   :/:
#   (NP gasworks/NNS employee/NN)
#   who/WP
#   (CIRC between/IN 1971/YEAR and/CC 1972/YEAR)
#   (VP
#     (VP (VP killed/VBD) (NP six/CD people/NNS))
#     (CIRC for/IN (NP (NP the/DT purpose/NN) of/OF (NP robbery/NN))))
#   ;/:
#   (VP
#     (VP died/VBN)
#     (CIRC from/IN (NP an/DT undisclosed/JJ illness/NN))
#     (CIRC in/IN 2013/YEAR))
#   ./.)
# Hugo Schenk:
# (S
#   (NE Hugo/NNP Schenk/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE Viennese/JJ (NE Housemaids/NNP Killer/NNP))
#   ''/''
#   ;/:
#   (NP swindler/NN)
#   who/WP
#   (VP
#     (VP (VP killed/VBD) (NP four/CD maids/NNS))
#     (CIRC in/IN 1883/YEAR)
#     (CIRC with/IN 1883/YEAR))
#   his/PRP$
#   (NP 1883/CD accomplice/NN)
#   (NE Karl/NNP Schlossarek/NNP)
#   ;/:
#   (VP suspected/VBN)
#   of/OF
#   more/JJR
#   (NP murders/NNS)
#   ;/:
#   (VP executed/VBD)
#   1884./CD
#   (NE websiteSerial/JJ (NE Killer/NNP Calendar.com/NNP))
#   (NE access-date24/JJ (NE November/NNP))
#   2019/CD)
# Jack Unterweger:
# (S
#   (NE Jack/NNP Unterweger/NNP)
#   :/:
#   (NP author/NN)
#   and/CC
#   (NE (NE Sadomasochismsexual/NNP) (NP sadist/NN))
#   ;/:
#   (VP (VP convicted/VBN) of/OF (NP ten/JJ murders/NNS))
#   ;/:
#   (VP believed/VBN)
#   to/TO
#   (VP have/VB)
#   (VP (VP killed/VBN) (NP twelve/JJ women/NNS))
#   ;/:
#   (VP
#     (VP (VP committed/VBN) (NP suicide/NN))
#     (CIRC in/IN (NP prison/NN))
#     (CIRC in/IN 1994/YEAR))
#   ./.)
# Lainz Angels of DeathMaria Gruber:
# (S
#   (NE (NE Lainz/NNP Angels/NNP) of/OF (NE DeathMaria/NNP Gruber/NNP))
#   ,/,
#   (NE Irene/NNP Leidolf/NNP)
#   ,/,
#   (NE Stephanija/NNP Mayer/NNP)
#   and/CC
#   (NE Waltraud/NNP Wagner/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE (NE Lainz/NNP Angels/NNPS) of/OF (NE Death/NNP))
#   ''/''
#   ;/:
#   (NP nurses/NNS)
#   (CIRC at/IN (NE the/DT (NE Lainz/NNP General/NNP Hospital/NNP)))
#   (CIRC in/IN (NE Vienna/NNP))
#   who/WP
#   (VP admitted/VBD)
#   to/TO
#   (VP
#     (VP (VP murdering/VBG) (NP 49/CD patients/NNS))
#     (CIRC between/IN 1983/YEAR and/CC 1989/YEAR))
#   ./.)
# Guido Zingerle:
# (S
#   (NE Guido/NNP Zingerle/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE (NE Monster/NNP) of/OF (NE Tyrol/NNP))
#   ''/''
#   ;/:
#   (NE Italian/NNP)
#   who/WP
#   brutally/RB
#   (VP
#     (VP (VP raped/VBD) (NP women/NNS))
#     (CIRC in/IN (NE Italy/NNP) and/CC (NE Austria/NNP))
#     (CIRC between/IN 1946/YEAR and/CC 1950/YEAR))
#   ,/,
#   1950/YEAR
#   (VP killing/VBG)
#   1950/YEAR
#   (CIRC at/IN 1950/CD)
#   least/JJS
#   two/CD
#   by/IN
#   (VP burying/VBG)
#   them/PRP
#   (CIRC under/IN (NP (NP a/DT pile/NN) of/OF (NP stones/NNS)))
#   ;/:
#   (VP
#     (VP died/VBN)
#     (CIRC in/IN (NP prison/NN))
#     (CIRC from/IN (NP liver/NN cancer/NN))
#     (CIRC in/IN 1962/YEAR))
#   ./.)
# The Bahamas:
# (S (NE The/DT (NE Bahamas/NNPS)))
# Cordell Farrington:
# (S
#   (NE Cordell/NNP Farrington/NNP)
#   :/:
#   (VP (VP killed/VBD) (NP four/CD children/NNS))
#   and/CC
#   his/PRP$
#   (NP homosexual/JJ lover/NN)
#   (CIRC from/IN 2002/YEAR to/TO 2003/YEAR)
#   ;/:
#   2003/YEAR
#   (VP sentenced/VBN)
#   2003/YEAR
#   to/TO
#   (NP 2003/CD death/NN)
#   and/CC
#   later/RB
#   (VP (VP commuted/VBN) to/TO (NP life/NN imprisonment/NN))
#   ./.)
# Michaiah Shobek:
# (S
#   (NE Michaiah/NNP Shobek/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE (NE The/DT (NE Angels/NNP)) of/OF (NE Lucifer/NNP Killer/NNP))
#   ''/''
#   ;/:
#   (NE (NE American/NNP) (NP emigrant/NN))
#   who/WP
#   (VP murdered/VBD)
#   three/CD
#   (NE (NE fellow/JJ (NE US/NNP)) (NP tourists/NNS))
#   (CIRC from/IN 1973/YEAR to/TO 1974/YEAR)
#   ;/:
#   1974/YEAR
#   (VP executed/VBN)
#   1976/YEAR
#   ./.)
# Roshu Kha:
# (S
#   (NE Roshu/NNP Kha/NNP)
#   :/:
#   (VP (VP enraged/VBD) (CIRC over/IN (NP rejection/NN)))
#   by/IN
#   his/PRP$
#   (NP lover/NN)
#   ,/,
#   (NE Roshu/NNP)
#   (VP
#     (VP killed/VBD)
#     (CIRC at/IN (NP least/JJS eleven/JJ garment/JJ workers/NNS))
#     (CIRC in/IN (NE Chandpur/NNP District/NNP)))
#   ./.
#   He/PRP
#   (VP pretended/VBD)
#   to/TO
#   (VP love/VB)
#   them/PRP
#   ,/,
#   later/RB
#   (VP killing/VBG)
#   them/PRP
#   brutally/RB
#   ./.
#   (VP
#     (VP date23/VB)
#     (NE (NE April/NNP) (NP 2015/CD newspaperThe/NN)))
#   (NE Guardian/NNP)
#   (/(
#   (NE Nigeria/NNP)
#   )/)
#   (NP The/DT Guardian/JJ locationLagos/NN)
#   ,/,
#   (NE Nigeria/NNP)
#   (NE access-date24/JJ (NE November/NNP))
#   2019/CD)
# Ershad Sikder:
# (S
#   (NE Ershad/NNP Sikder/NNP)
#   :/:
#   (NP
#     (NP career/NN criminal/NN)
#     and/CC
#     (NP corrupt/JJ politician/NN))
#   responsible/JJ
#   (CIRC
#     for/IN
#     (NP
#       (NP the/DT torture-murders/NNS)
#       of/OF
#       (NP numerous/JJ people/NNS)))
#   in/IN
#   the/DT
#   1990s/CD
#   ;/:
#   (VP
#     (VP convicted/VBN)
#     (CIRC on/IN (NP (NP seven/CD counts/NNS) of/OF (NP murder/NN))))
#   and/CC
#   (VP (VP executed/VBN) (CIRC in/IN 2004/YEAR))
#   ./.)
# Ivan Kulesh:
# (S
#   (NE Ivan/NNP Kulesh/NNP)
#   :/:
#   (NP drunkard/NN)
#   who/WP
#   (VP
#     (VP (VP killed/VBD) (NP three/CD saleswomen/NNS))
#     (CIRC between/IN 2013/YEAR and/CC 2014/YEAR)
#     (CIRC in/IN 2014/YEAR))
#   the/DT
#   2014/CD
#   (NE Grodno/NNP Region/NNP)
#   ;/:
#   (VP executed/VBD)
#   2016/CD
#   ./.)
# Eduard Lykov:
# (S
#   (NE Eduard/NNP Lykov/NNP)
#   :/:
#   (NP Russian/JJ immigrant/NN)
#   who/WP
#   (VP
#     (VP (VP killed/VBD) (NP five/CD people/NNS))
#     (CIRC in/IN (NP drunken/JJ quarrels/NNS))
#     (CIRC from/IN 2002/YEAR to/TO 2011/YEAR))
#   ;/:
#   2011/YEAR
#   (VP executed/VBN)
#   2014/YEAR
#   ./.)
# Gennady Mikhasevich:
# (S
#   (NE Gennady/JJ (NE Mikhasevich/NNP))
#   :/:
#   (NE
#     (NE Voluntary/JJ (NE Peoples/NNP Druzhinapolice/NNP))
#     (NP volunteer/NN))
#   who/WP
#   (VP investigated/VBD)
#   his/PRP$
#   (NP
#     (NP own/JJ mission-oriented/JJ murders/NNS)
#     of/OF
#     (NP 36/CD women/NNS))
#   (CIRC between/IN 1971/YEAR and/CC 1985/YEAR)
#   ;/:
#   1985/YEAR
#   (VP executed/VBN)
#   1985/YEAR
#   (CIRC in/IN 1987/YEAR)
#   ./.)
# Igor Mirenkov:
# (S
#   (NE Igor/NNP Mirenkov/NNP)
#   :/:
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE the/DT (NE Svietlahorsk/NNP Nightmare/NNP))
#   ''/''
#   ;/:
#   (VP (VP child/VB) (NP killer/NN))
#   who/WP
#   (VP
#     (VP (VP murdered/VBD) (NP six/CD boys/NNS))
#     (CIRC from/IN 1990/YEAR to/TO 1993/YEAR))
#   ;/:
#   1993/YEAR
#   (VP executed/VBN)
#   1993/YEAR
#   (CIRC in/IN 1996/YEAR)
#   ./.)
# The Polotsk FourSergey Pugachev:
# (S
#   (NE The/DT (NE Polotsk/NNP FourSergey/NNP Pugachev/NNP))
#   and/CC
#   (NE Alexander/NNP Burdenko/NNP)
#   :/:
#   (NP leaders/NNS)
#   of/OF
#   the/DT
#   ``/``
#   (NE Polotsk/NNP Four/NNP)
#   ''/''
#   ;/:
#   (NP criminals/NNS)
#   responsible/JJ
#   for/IN
#   (VP
#     (VP
#       (VP killing/VBG)
#       (NP
#         (NP two/CD girls/NNS)
#         and/CC
#         (NP two/CD car/NN enthusiasts/NNS)))
#     (CIRC from/IN 2001/YEAR to/TO 2002/YEAR))
#   ,/,
#   2002/YEAR
#   as/RB
#   2002/YEAR
#   well/RB
#   2002/YEAR
#   (CIRC as/IN (NP 2002/CD numerous/JJ robberies/NNS))
#   (CIRC with/IN (NP two/CD other/JJ accomplices/NNS))
#   ;/:
#   (NE Pugachev/NNP)
#   (VP was/VBD)
#   (VP (VP executed/VBN) (CIRC in/IN 2005/YEAR and/CC 2005/CD))
#   (NE Burdenko/NNP)
#   (VP was/VBD)
#   (VP (VP sentenced/VBN) to/TO (NP life/NN imprisonment/NN))
#   ./.
#   dateJuly/RB
#   12/CD
#   ,/,
#   (NP 2005/CD newspaperSovetskaya/NN)
#   (NE Belorussiya/NNP –/NNP Belarus/NNP Segodnya/NNP)
#   (VP (VP languageru/VBD) (NE access-date24/JJ (NE November/NNP)))
#   2019/CD)
# Alexander Sergeychik:
# (S
#   (NE Alexander/NNP Sergeychik/NNP)
#   :/:
#   (VP
#     (VP (VP killed/VBN) (NP six/CD people/NNS))
#     (CIRC from/IN 2000/YEAR to/TO 2006/YEAR)
#     (CIRC in/IN 2006/YEAR))
#   the/DT
#   2006/CD
#   (NE Shchuchyn/NNP DistrictShchuchyn/NNP)
#   and/CC
#   (NE Grodno/NNP Districts/NNP)
#   ;/:
#   (VP confessed/VBN)
#   to/TO
#   (VP (VP twelve/VB) (NP murders/NNS))
#   ;/:
#   (VP executed/VBN)
#   2007/CD
#   ./.)
# Marie Alexandrine Becker:
# (S
#   (NE Marie/NNP Alexandrine/NNP Becker/NNP)
#   :/:
#   (VP
#     (VP poisoned/VBN)
#     (CIRC at/IN (NP least/JJS eleven/JJ people/NNS))
#     (CIRC with/IN (NE Digitalis/NNP)))
#   ;/:
#   (VP (VP sentenced/VBN) to/TO (NP life/NN imprisonment/NN))
#   ;/:
#   died/JJ
#   1938/CD
#   ./.)
# Jan Caubergh:
# (S
#   (NE Jan/NNP Caubergh/NNP)
#   :/:
#   (VP strangled/VBD)
#   his/PRP$
#   (NP pregnant/JJ neighbour/NN)
#   ,/,
#   his/PRP$
#   (NP girlfriend/NN)
#   and/CC
#   their/PRP$
#   (NP child/NN)
#   (CIRC in/IN 1979/YEAR)
#   ;/:
#   1979/YEAR
#   (VP sentenced/VBN)
#   1979/YEAR
#   to/TO
#   (NP 1979/CD death/NN)
#   but/CC
#   it/PRP
#   (VP was/VBD)
#   (VP (VP converted/VBN) to/TO (NP life/NN imprisonment/NN))
#   ;/:
#   (VP
#     (VP (VP was/VBD) (NP the/DT longest-serving/JJ prisoner/NN))
#     (CIRC in/IN (NP the/DT country/NN)))
#   until/IN
#   his/PRP$
#   (NP death/NN)
#   (CIRC in/IN 2013/YEAR)
#   ./.)
# Étienne Dedroog:
# (S
#   (NE Étienne/JJ (NE Dedroog/NNP))
#   :/:
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE Lodgers/NNP Killer/NNP)
#   ''/''
#   ;/:
#   (VP (VP killed/VBD) (NE a/DT (NE Bed/NNP)))
#   and/CC
#   (NP breakfastB/NN)
#   &/CC
#   (NE (NE B/NNP) (NP owner/NN))
#   (CIRC in/IN (NE France/NNP) and/CC (NP a/DT couple/NN))
#   (CIRC in/IN (NE Belgium/NNP))
#   (CIRC from/IN (NE October/NNP) to/TO (NE November/NNP))
#   2011/CD
#   ;/:
#   also/RB
#   (VP
#     (VP (VP suspected/VBD) of/OF (NP a/DT murder/NN))
#     (CIRC in/IN (NE Spain/NNP)))
#   ;/:
#   (VP (VP sentenced/VBN) to/TO (NP life/NN imprisonment/NN))
#   ./.)
# Marc Dutroux:
# (S
#   (NE Marc/NNP Dutroux/NNP)
#   :/:
#   (VP convicted/VBN)
#   of/OF
#   (VP having/VBG)
#   (VP kidnapped/VBN)
#   ,/,
#   (VP tortured/VBN)
#   and/CC
#   sexually/RB
#   abused/JJ
#   (NP six/CD girls/NNS)
#   (VP
#     (VP ranging/VBG)
#     (CIRC in/IN (NP age/NN))
#     (CIRC from/IN 8/YEAR to/TO 19/YEAR))
#   ,/,
#   19/YEAR
#   (CIRC during/IN 1995/YEAR and/CC 1996/YEAR)
#   ./.
#   Four/YEAR
#   of/OF
#   Four/YEAR
#   his/PRP$
#   (NP Four/CD victims/NNS)
#   (VP were/VBD)
#   (VP murdered/VBN)
#   ;/:
#   the/DT
#   final/JJ
#   two/CD
#   (VP were/VBD)
#   (VP rescued/VBN)
#   ./.)
# Staf Van Eyken:
# (S
#   (NE Staf/NNP Van/NNP Eyken/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE (NE Vampire/NNP) of/OF (NE Muizen/NNP))
#   ''/''
#   ;/:
#   (VP
#     (VP
#       (VP (VP raped/VBD) and/CC (VP strangled/VBD))
#       (NP three/CD women/NNS))
#     (CIRC from/IN 1971/YEAR to/TO 1972/YEAR)
#     (CIRC in/IN 1972/CD))
#   (NE Muizen/NNP)
#   and/CC
#   (NE Bonheiden/NNP)
#   ;/:
#   (VP (VP sentenced/VBN) to/TO (NP death/NN))
#   ,/,
#   (VP (VP commuted/VBN) to/TO (NP life/NN imprisonment/NN))
#   ./.)
# Renaud Hardy:
# (S
#   (NE Renaud/NNP Hardy/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NP Parkinsons/NNS)
#   (NE Murderer/NNP)
#   ''/''
#   ;/:
#   (VP
#     (VP murdered/VBN)
#     (CIRC between/IN two/YEAR and/CC (NP three/CD women/NNS))
#     (CIRC in/IN (NE the/DT (NE Flemish/NNP Community/NNP)))
#     (CIRC from/IN 2009/YEAR to/TO 2015/YEAR))
#   ;/:
#   2015/YEAR
#   (VP sentenced/VBN)
#   2015/YEAR
#   to/TO
#   (NP 2015/CD life/NN imprisonment/NN)
#   ./.)
# Ronald Janssen:
# (S
#   (NE Ronald/NNP Janssen/NNP)
#   :/:
#   (VP
#     (VP (VP killed/VBD) (NP a/DT woman/NN))
#     (CIRC in/IN 2007/YEAR and/CC 2007/YEAR))
#   later/RBR
#   2007/YEAR
#   his/PRP$
#   (NP 2007/CD neighbour/NN)
#   and/CC
#   her/PRP$
#   (NP boyfriend/NN)
#   (CIRC in/IN 2010/YEAR)
#   (CIRC in/IN 2010/CD)
#   (NE Flemish/NNP Brabant/NNP)
#   ;/:
#   (VP (VP admitted/VBN) to/TO (NP five/CD rapes/NNS))
#   (VP (VP committed/VBN) (CIRC in/IN 1993/YEAR))
#   ,/,
#   1993/YEAR
#   but/CC
#   1993/YEAR
#   (VP is/VBZ)
#   1993/YEAR
#   (VP suspected/VBN)
#   1993/YEAR
#   of/OF
#   20/YEAR
#   ;/:
#   20/YEAR
#   (VP sentenced/VBN)
#   20/YEAR
#   to/TO
#   (NP 20/CD life/NN imprisonment/NN)
#   (CIRC in/IN 2011/YEAR)
#   ./.)
# Marie-Thérèse Joniaux:
# (S
#   (NE Marie-Thérèse/JJ (NE Joniaux/NNP))
#   :/:
#   (VP poisoned/VBD)
#   three/CD
#   of/OF
#   her/PRP$
#   (NP family/NN members/NNS)
#   (CIRC between/IN 1894/YEAR and/CC 1895/YEAR)
#   ;/:
#   1895/YEAR
#   (VP sentenced/VBN)
#   1895/YEAR
#   to/TO
#   (NP 1895/CD death/NN)
#   (CIRC in/IN 1895/YEAR)
#   ,/,
#   1895/YEAR
#   but/CC
#   1895/YEAR
#   (VP was/VBD)
#   1895/YEAR
#   (VP commuted/VBN)
#   1895/YEAR
#   to/TO
#   (NP 1895/CD life/NN imprisonment/NN)
#   ;/:
#   (VP
#     (VP died/VBN)
#     (CIRC in/IN (NE Antwerp/NNP))
#     (CIRC in/IN 1923/YEAR))
#   ./.)
# András Pándy:
# (S
#   (NE András/NNP Pándy/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE Vader/NNP Blauwbaard/NNP)
#   ''/''
#   (/(
#   (NE Father/NNP Bluebeard/NNP)
#   )/)
#   ;/:
#   (NP Hungarian/JJ immigrant/NN)
#   (VP
#     (VP convicted/VBN)
#     of/OF
#     (NP (NP the/DT murder/NN) and/CC (NP rape/NN)))
#   of/OF
#   his/PRP$
#   (NP (NP two/CD wives/NNS) and/CC (NP four/CD children/NNS))
#   (CIRC in/IN (NE Brussels/NNP))
#   (CIRC between/IN 1986/YEAR and/CC 1990/YEAR)
#   (CIRC with/IN 1990/YEAR)
#   (NP the/DT (NP 1990/CD aid/NN))
#   of/OF
#   his/PRP$
#   (NP daughter/NN)
#   ,/,
#   (VP (VP Ágnes/VBZ) (NE Pándy/NNP))
#   ;/:
#   (VP
#     (VP died/VBD)
#     (CIRC in/IN (NP prison/NN))
#     (CIRC in/IN 2013/YEAR))
#   ./.)
# Nestor Pirotte:
# (S
#   (NE Nestor/NNP Pirotte/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE Crazy/NNP Killer/NNP)
#   ''/''
#   ;/:
#   (VP considered/VBN)
#   one/CD
#   of/OF
#   (NP the/DT worst/JJS Belgian/JJ criminals/NNS)
#   ,/,
#   responsible/JJ
#   (CIRC for/IN (NP the/DT murders/NNS))
#   of/OF
#   up/IN
#   to/TO
#   (NP seven/CD people/NNS)
#   (CIRC from/IN 1954/YEAR to/TO 1981/YEAR)
#   ,/,
#   1981/YEAR
#   (VP including/VBG)
#   1981/YEAR
#   his/PRP$
#   (NP 1981/CD great-aunt/NN)
#   ;/:
#   (VP
#     (VP died/VBN)
#     (CIRC from/IN (NP a/DT heart/NN attack/NN))
#     (CIRC in/IN 2000/YEAR))
#   ./.)
# the Brabant:
# (S
#   (NP Brabant/JJ killers/NNS)
#   :/:
#   (NP (NP gang/NN) of/OF (NP serial/JJ killers/NNS))
#   who/WP
#   (VP (VP operated/VBD) (CIRC in/IN (NE the/DT (NE Brabant/NNP))))
#   (/(
#   (NP province/NN)
#   )/)
#   (NE (NE Brabant/NNP) (NP province/NN))
#   (CIRC from/IN 1982/YEAR)
#   (CIRC until/IN 1985/YEAR)
#   ;/:
#   1985/YEAR
#   (VP (VP murdered/VBD) (NP 28/CD people/NNS))
#   and/CC
#   injured/JJ
#   40/CD
#   ./.)
# The Butcher:
# (S
#   (NE The/DT (NE Butcher/NNP))
#   of/OF
#   (NP Mons/NNS)
#   :/:
#   (NP unidentified/JJ serial/JJ killer/NN)
#   who/WP
#   (VP
#     (VP (VP committed/VBD) (NP five/CD murders/NNS))
#     (CIRC from/IN (NE January/NNP)))
#   1996/CD
#   to/TO
#   (NE July/NNP)
#   1997/CD
#   (CIRC in/IN (NE Mons/NNP))
#   ./.
#   (NE (NE Montenegrin/NNP) (NP murderer/NN))
#   (NE Smail/NNP Tulja/NNP)
#   (VP is/VBZ)
#   (VP suspected/VBN)
#   of/OF
#   (VP (VP being/VBG) (NE the/DT (NE Butcher/NNP)))
#   ./.)
# Ramiro Artieda:
# (S
#   (NE Ramiro/NNP Artieda/NNP)
#   :/:
#   (VP killed/VBD)
#   his/PRP$
#   (NP brother/NN)
#   in/IN
#   the/DT
#   early/JJ
#   1920s/CD
#   (CIRC for/IN (NP monetary/JJ purposes/NNS))
#   ;/:
#   (VP
#     (VP emigrated/VBN)
#     to/TO
#     (NE the/DT (NE United/NNP States/NNPS)))
#   but/CC
#   later/RB
#   (VP
#     (VP
#       (VP (VP returned/VBD) and/CC (VP killed/VBD))
#       (NP seven/CD women/NNS))
#     (CIRC until/IN 1938/YEAR))
#   ;/:
#   1938/YEAR
#   (VP was/VBD)
#   1938/YEAR
#   (VP arrested/VBN)
#   1938/YEAR
#   (CIRC in/IN 1939/YEAR)
#   ,/,
#   1939/YEAR
#   (VP confessed/VBD)
#   1939/YEAR
#   and/CC
#   1939/YEAR
#   (VP was/VBD)
#   1939/YEAR
#   (VP executed/VBN)
#   1939/YEAR
#   (CIRC by/IN 1939/YEAR)
#   (VP (VP firing/VBG) (NP 1939/CD squad/NN))
#   ./.)
# José Augusto:
# (S
#   (NE José/NNP Augusto/NNP)
#   do/VBP
#   (NE Amaral/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE Preto/NNP Amaral/NNP)
#   ''/''
#   ;/:
#   first/RB
#   (VP (VP documented/VBD) (NP Brazilian/JJ serial/JJ killer/NN))
#   ;/:
#   (VP (VP suspected/VBN) of/OF (NP murdering/NN))
#   and/CC
#   then/RB
#   (VP
#     (VP
#       (VP raping/VBG)
#       (NP
#         (NP the/DT corpses/NNS)
#         of/OF
#         (NP three/CD young/JJ men/NNS)))
#     (CIRC in/IN (NE São/NNP Paulo/NNP))
#     (CIRC in/IN 1926/YEAR))
#   ;/:
#   1926/YEAR
#   (VP died/VBN)
#   1926/YEAR
#   (CIRC from/IN (NP 1926/CD tuberculosis/NN))
#   while/IN
#   (VP imprisoned/VBN)
#   before/IN
#   he/PRP
#   could/MD
#   (VP be/VB)
#   (VP (VP put/VBN) (CIRC on/IN (NP trial/NN)))
#   ./.)
# Marcelo Costa de Andrade:
# (S
#   (NE (NE Marcelo/NNP Costa/NNP) de/OF (NE Andrade/NNP))
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE (NE The/DT (NE Vampire/NNP)) of/OF (NE Niterói/NNP))
#   ''/''
#   ;/:
#   (VP
#     (VP (VP raped/VBD) and/CC (VP killed/VBD))
#     (NP fourteen/JJ children/NNS))
#   ./.)
# Marcelo de Jesus Silva:
# (S
#   (NE (NE (NE Marcelo/NNP) de/OF (NE Jesus/NNP)) (NP Silva/NN))
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE Chucky/NNP)
#   ''/''
#   ;/:
#   (NE (NE Dwarfismdwarf/NNP) (NP man/NN))
#   (VP
#     (VP convicted/VBD)
#     of/OF
#     (NP (NP twenty/NN counts/NNS) of/OF (NP murder/NN)))
#   ,/,
#   (NP robbery/NN)
#   ,/,
#   (NP (NP drug/NN trafficking/NN) and/CC (NP death/NN squad/NN))
#   ./.)
# José Paz Bezerra:
# (S
#   (NE José/NNP Paz/NNP Bezerra/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE The/DT (NE Morumbi/NNP Monster/NNP))
#   ''/''
#   ;/:
#   sexually/RB
#   (VP violated/VBN)
#   ,/,
#   (VP (VP tortured/VBN) and/CC (VP murdered/VBD))
#   more/JJR
#   (CIRC than/IN (NP twenty/JJ women/NNS))
#   (CIRC in/IN (NE São/NNP Paulo/NNP) and/CC (NE Pará/NNP))
#   (CIRC during/IN (NP the/DT 1960s/NNS) and/CC 1970s/CD)
#   ;/:
#   (VP (VP sentenced/VBN) to/TO (NP 30/CD years/NNS))
#   imprisonment/JJ
#   and/CC
#   (VP (VP released/VBN) (CIRC in/IN (NP 2001./CD date19/NNS)))
#   (NE (NE March/NNP) (NP 2018/CD websiteO/NN))
#   (NE Aprendiz/NNP Verde/NNP)
#   (VP (VP languagept/VBD) (NE access-date24/JJ (NE November/NNP)))
#   2019/CD)
# Febrônio Índio:
# (S
#   (NE Febrônio/NNP Índio/NNP)
#   do/VBP
#   (NE Brasil/NNP)
#   :/:
#   (NP
#     (NP delusional/JJ religious/JJ maniac/NN)
#     and/CC
#     (NP habitual/JJ criminal/NN))
#   who/WP
#   (VP murdered/VBD)
#   at/IN
#   least/JJS
#   (NP six/CD people/NNS)
#   (CIRC from/IN 1925/YEAR to/TO 1927/YEAR)
#   ,/,
#   1927/YEAR
#   mostly/RB
#   (NP (NP 1927/CD young/JJ boys/NNS) and/CC (NP teens/NNS))
#   ;/:
#   (VP
#     (VP acquitted/VBN)
#     (CIRC by/IN (NP (NP reason/NN) of/OF (NP insanity/NN))))
#   and/CC
#   (VP (VP sent/VBD) to/TO (NP a/DT mental/JJ institution/NN))
#   ,/,
#   in/IN
#   which/WDT
#   he/PRP
#   (VP
#     (VP died/VBD)
#     (CIRC in/IN 1989/YEAR)
#     (CIRC
#       from/IN
#       (NP 1989/CD chronic/JJ obstructive/JJ pulmonary/JJ disease/NN)))
#   ./.)
# Abraão José Bueno:
# (S
#   (NE Abraão/NNP José/NNP Bueno/NNP)
#   :/:
#   (NE (NE (NE Rio/NNP) de/OF (NE Janeiro/NNP)) (NP nurse/NN))
#   who/WP
#   (VP (VP killed/VBD) (NP four/CD child/NN patients/NNS))
#   ;/:
#   (VP
#     (VP
#       (VP sentenced/VBN)
#       to/TO
#       (NP 110/CD years/NNS imprisonment/NN))
#     (CIRC in/IN (NP 2005./CD date16/NN)))
#   (NE (NE May/NNP) (NP 2008/CD websiteÚltimo/NN))
#   (NE Segundo/NNP)
#   (VP
#     (VP languagept/VBD)
#     (NE
#       (NE access-date24/JJ (NE November/NNP))
#       (NP 2019/CD url-statusdead/JJ archive-urlhttps/NN)))
#   :/:
#   (NP //web.archive.org/web/20080619095227/http/NN)
#   :/:
#   //ultimosegundo.ig.com.br/brasil/2008/05/16/ex_enfermeiro_que_matou_criancas_em_hospital_do_rio_e_condenado_a_110_anos_1315150.html/JJ
#   archive-dateJune/JJ
#   19/CD
#   ,/,
#   2008/CD)
# Francisco das:
# (S
#   (NE (NE Francisco/NNP) (NP das/NN))
#   (NE (NE Chagas/NNP Rodrigues/NNP) de/OF (NE Brito/NNP))
#   :/:
#   (NP pedophile/NN)
#   who/WP
#   sexually/RB
#   (VP abused/VBD)
#   ,/,
#   (VP
#     (VP (VP murdered/VBN) and/CC (VP mutilated/VBN))
#     (CIRC between/IN 30/YEAR and/CC (NP 42/CD young/JJ boys/NNS))
#     (CIRC from/IN 1989/YEAR to/TO 2003/YEAR)
#     (CIRC in/IN 2003/CD))
#   (NE Maranhão/NNP)
#   and/CC
#   (NE Pará/NNP)
#   ;/:
#   (VP (VP sentenced/VBD) to/TO (NP 217/CD years/NNS imprisonment/NN))
#   ./.)
# Pedro Rosa da Conceição:
# (S
#   (NE (NE Pedro/NNP Rosa/NNP) (NP da/NN Conceição/NN))
#   :/:
#   (NP Brazilian/JJ mass/NN murderer/NN)
#   who/WP
#   (VP (VP killed/VBD) (NP three/CD people/NNS))
#   and/CC
#   (VP
#     (VP (VP wounded/VBD) (NP thirteen/JJ others/NNS))
#     (CIRC on/IN (NE April/NNP)))
#   22/CD
#   ,/,
#   1904/CD
#   ./.
#   (VP Killed/VBN)
#   his/PRP$
#   (NP (NP cellmate/NN) and/CC (NP a/DT guard/NN))
#   (CIRC in/IN 1911/YEAR)
#   ,/,
#   1911/YEAR
#   and/CC
#   1911/YEAR
#   (VP is/VBZ)
#   1911/YEAR
#   (VP said/VBD)
#   1911/YEAR
#   to/TO
#   1911/YEAR
#   (VP have/VB)
#   1911/YEAR
#   (VP murdered/VBN)
#   1911/YEAR
#   (NP
#     (NP a/DT (NP 1911/CD family/NN))
#     of/OF
#     (NP twelve/NN people/NNS))
#   (CIRC
#     in/IN
#     (NP (NP an/DT unspecified/JJ date/NN) and/CC (NP year/NN)))
#   ./.
#   (NE Died/NNP)
#   (CIRC in/IN 1919/YEAR)
#   ./.)
# Pedro Rodrigues Filho:
# (S
#   (NE Pedro/NNP Rodrigues/NNP Filho/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE Pedrinho/NNP Matador/NNP)
#   ''/''
#   ;/:
#   (VP
#     (VP
#       (VP (VP convicted/VBN) and/CC (VP sentenced/VBN))
#       to/TO
#       (NP 128/CD years/NNS imprisonment/NN))
#     (CIRC for/IN (NP 70/CD murders/NNS)))
#   ;/:
#   however/RB
#   ,/,
#   the/DT
#   maximum/JJ
#   one/CD
#   can/MD
#   (VP (VP serve/VB) (CIRC in/IN (NE Brazil/NNP)))
#   (VP (VP is/VBZ) (NP 30/CD years/NNS))
#   ;/:
#   (VP claimed/VBN)
#   to/TO
#   (VP have/VB)
#   (VP killed/VBN)
#   more/JJR
#   (CIRC than/IN (NP 100/CD victims/NNS))
#   ,/,
#   (VP (VP including/VBG) (NP 40/CD prison/NN inmates/NNS))
#   ./.)
# Roneys Fon Firmino Gomes:
# (S
#   (NE Roneys/NNP Fon/NNP Firmino/NNP Gomes/NNP)
#   :/:
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE Tower/NNP Maniac/NNP)
#   ''/''
#   ;/:
#   (VP murdered/VBN)
#   at/IN
#   least/JJS
#   (NP six/CD prostitutes/NNS)
#   (CIRC in/IN (NP the/DT city/NN))
#   of/OF
#   (NE Maringá/NNP)
#   (CIRC between/IN 2005/YEAR and/CC 2015/YEAR)
#   ,/,
#   2015/YEAR
#   (VP disposing/VBG)
#   2015/YEAR
#   of/OF
#   2015/YEAR
#   their/PRP$
#   (NP 2015/CD bodies/NNS)
#   (CIRC under/IN (NP electric/JJ towers/NNS))
#   ;/:
#   (VP (VP sentenced/VBN) to/TO (NP 21/CD years/NNS imprisonment/NN))
#   ./.)
# Francisco de Assis Pereira:
# (S
#   (NE (NE Francisco/NNP) de/OF (NE Assis/NNP Pereira/NNP))
#   :/:
#   (NP (NP rapist/NN) and/CC (NP serial/JJ killer/NN))
#   ,/,
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE O/NNP Maníaco/NNP)
#   do/VBP
#   (NE Parque/NNP)
#   ''/''
#   (/(
#   (NE The/DT (NE Park/NNP Maniac/NNP))
#   )/)
#   ;/:
#   (VP (VP arrested/VBN) (CIRC for/IN (NP the/DT torture/NN)))
#   ,/,
#   (NP
#     (NP (NP rape/NN) and/CC (NP death/NN))
#     of/OF
#     (NP eleven/JJ women/NNS))
#   and/CC
#   for/IN
#   (VP assaulting/VBG)
#   nine/CD
#   (CIRC in/IN (NP a/DT park/NN))
#   (CIRC in/IN (NE São/NNP Paulo/NNP))
#   during/IN
#   the/DT
#   1990s/CD
#   ./.)
# Tiago Henrique Gomes:
# (S
#   (NE Tiago/NNP Henrique/NNP Gomes/NNP)
#   (VP (VP da/VBZ) (NP Rocha/NN))
#   :/:
#   (NP security/NN guard/NN)
#   who/WP
#   (VP has/VBZ)
#   (VP claimed/VBN)
#   to/TO
#   (VP have/VB)
#   (VP
#     (VP (VP killed/VBN) (NP 39/CD people/NNS))
#     (CIRC in/IN (NP the/DT state/NN)))
#   of/OF
#   (NE Goiás/NNP)
#   ./.)
# Edson Izidoro Guimarães:
# (S
#   (NE Edson/NNP Izidoro/NNP Guimarães/NNP)
#   :/:
#   (NP nurse/NN)
#   who/WP
#   (VP
#     (VP (VP killed/VBD) (NP four/CD patients/NNS))
#     (CIRC
#       in/IN
#       (NE
#         (NE (NE the/DT (NE Rio/NNP)) de/OF (NE Janeiro/NNP))
#         (NP neighborhood/NN))))
#   of/OF
#   (NE Méier/NNP)
#   ;/:
#   (VP (VP suspected/VBN) of/OF (NP 131/CD deaths/NNS))
#   in/IN
#   total/JJ
#   ./.)
# José Vicente Matias:
# (S
#   (NE José/NNP Vicente/NNP Matias/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE Corumbá/NNP)
#   ''/''
#   ;/:
#   (NP former/JJ artisan/NNS)
#   who/WP
#   (VP raped/VBD)
#   ,/,
#   (VP
#     (VP
#       (VP (VP murdered/VBN) and/CC (VP dismembered/VBN))
#       (NP six/CD women/NNS))
#     (CIRC between/IN 1999/YEAR and/CC 2005/YEAR))
#   ,/,
#   2005/YEAR
#   (VP cannibalizing/VBG)
#   one/YEAR
#   of/OF
#   one/YEAR
#   them/PRP
#   one/YEAR
#   ;/:
#   one/YEAR
#   (VP sentenced/VBN)
#   one/YEAR
#   to/TO
#   (NP 23/CD years/NNS)
#   imprisonment/JJ
#   ./.
#   (NP date4/NN)
#   (NE June/NNP)
#   2008/CD
#   (NE newspaperJornal/JJ (NE Pequeno/NNP))
#   (VP
#     (VP languagept/VBD)
#     (NE
#       (NE access-date24/JJ (NE November/NNP))
#       (NP 2019/CD url-statusdead/JJ archive-urlhttps/NN)))
#   :/:
#   (NP //web.archive.org/web/20080609012441/http/NN)
#   :/:
#   //www.jornalpequeno.com.br/2008/6/4/Pagina79933.htm/JJ
#   archive-dateJune/JJ
#   9/CD
#   ,/,
#   2008/CD)
# Florisvaldo de Oliveira:
# (S
#   (NE (NE Florisvaldo/NNP) de/OF (NE Oliveira/NNP))
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE Cabo/NNP Bruno/NNP)
#   ''/''
#   ;/:
#   (NP former/JJ police/NNS officer/NN)
# ...
#   ``/``
#   (NE The/DT (NE East/NNP FinchleyFinchley/NNP Baby/NNP Farmers/NNP))
#   ''/''
#   ;/:
#   (NP baby/NN farmers/NNS)
#   who/WP
#   (VP (VP used/VBD) (NP chlorodyne/NN))
#   to/TO
#   (VP
#     (VP poison/VB)
#     (NP (NP an/DT unknown/JJ number/NN) of/OF (NP infants/NNS)))
#   ;/:
#   both/DT
#   (VP
#     (VP hanged/VBN)
#     (CIRC at/IN (NE the/DT (NE HM/NNP Prison/NNP Holloway/NNP)))
#     (CIRC in/IN 1903/YEAR))
#   ./.)
# Harold Shipman:
# (S
#   (NE Harold/NNP Shipman/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE Dr./NNP Death/NNP)
#   ''/''
#   ;/:
#   (NP doctor/NN)
#   (VP (VP convicted/VBD) of/OF (NP fifteen/JJ murders/NNS))
#   ;/:
#   a/DT
#   later/RBR
#   (NP inquiry/NN)
#   (VP stated/VBD)
#   he/PRP
#   (VP had/VBD)
#   (VP killed/VBN)
#   at/IN
#   least/JJS
#   215/CD
#   and/CC
#   possibly/RB
#   up/IN
#   to/TO
#   (NP 457/CD people/NNS)
#   (CIRC over/IN (NP a/DT 25-year/JJ period/NN))
#   ;/:
#   (VP
#     (VP (VP committed/VBN) (NP suicide/NN))
#     (CIRC in/IN 2004/YEAR)
#     (CIRC in/IN (NP 2004/CD prison/NN)))
#   ./.)
# George Joseph Smith:
# (S
#   (NE George/NNP Joseph/NNP Smith/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE The/DT (NE Brides/NNP))
#   (CIRC in/IN (NE the/DT (NE Bath/NNP)))
#   ''/''
#   (NP killer/NN)
#   who/WP
#   (VP (VP murdered/VBD) (NP three/CD women/NNS))
#   ./.)
# Rebecca Smith:
# (S
#   (NE Rebecca/NNP Smith/NNP)
#   (/(
#   (NP infanticide/NN)
#   )/)
#   (NE Rebecca/NNP Smith/NNP)
#   :/:
#   (VP poisoned/VBD)
#   her/PRP$
#   (NP infant/JJ son/NN)
#   (CIRC with/IN (NP arsenic/NN))
#   (CIRC in/IN 1849/YEAR)
#   ,/,
#   1849/YEAR
#   later/RB
#   1849/YEAR
#   (VP confessing/VBG)
#   1849/YEAR
#   to/TO
#   1849/YEAR
#   (VP doing/VBG)
#   1849/YEAR
#   the/DT
#   1849/CD
#   same/JJ
#   to/TO
#   seven/YEAR
#   of/OF
#   seven/YEAR
#   her/PRP$
#   (NP seven/CD other/JJ children/NNS)
#   ;/:
#   (VP executed/VBN)
#   1849/CD
#   ./.)
# John Straffen:
# (S
#   (NE John/NNP Straffen/NNP)
#   :/:
#   (VP
#     (VP (VP murdered/VBD) (NP three/CD children/NNS))
#     (CIRC between/IN 1951/YEAR and/CC 1952/YEAR))
#   ;/:
#   1952/CD
#   (NE (NE Britains/NNP) (NP longest-serving/JJ prisoner/NN))
#   until/IN
#   his/PRP$
#   (NP death/NN)
#   (CIRC in/IN 2007/YEAR)
#   ./.)
# Peter Sutcliffe:
# (S
#   (NE Peter/NNP Sutcliffe/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE Yorkshire/NNP Ripper/NNP)
#   ''/''
#   ;/:
#   (VP (VP convicted/VBN) (CIRC in/IN 1981/YEAR))
#   of/OF
#   1981/YEAR
#   (VP (VP murdering/VBG) (NP 1981/CD thirteen/JJ women/NNS))
#   and/CC
#   (VP attacking/VBG)
#   seven/CD
#   more/JJR
#   (CIRC from/IN 1975/YEAR to/TO 1980/YEAR)
#   ./.)
# Thomas Griffiths Wainewright:
# (S
#   (NE Thomas/NNP Griffiths/NNP Wainewright/NNP)
#   :/:
#   (NP artist/NN)
#   (VP considered/VBN)
#   to/TO
#   (VP have/VB)
#   (VP (VP poisoned/VBN) (NP four/CD people/NNS))
#   ./.)
# Brixton:
# (S
#   (NP Margaret/JJ Waters/NNS)
#   :/:
#   (NP baby/NN farmer/NN)
#   (CIRC from/IN (NE Brixton/NNP))
#   who/WP
#   (VP
#     (VP (VP drugged/VBD) and/CC (VP starved/VBD))
#     (NP the/DT infants/NNS))
#   in/IN
#   her/PRP$
#   (NP care/NN)
#   ;/:
#   (VP believed/VBN)
#   to/TO
#   (VP have/VB)
#   (VP
#     (VP killed/VBN)
#     (CIRC at/IN (NP least/JJS nineteen/JJ children/NNS)))
#   ;/:
#   (VP (VP executed/VBN) (CIRC on/IN 11/CD))
#   (NE October/NNP)
#   1870/CD
#   ./.)
# West:
# (S
#   (VP (VP Fred/VBN) (NE West/NNP))
#   and/CC
#   (NE Rosemary/NNP West/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE (NE House/NNP) of/OF (NE Horrors/NNPS))
#   ''/''
#   (NP murderers/NNS)
#   ;/:
#   she/PRP
#   (VP was/VBD)
#   (VP (VP convicted/VBN) of/OF (NP ten/JJ murders/NNS))
#   ;/:
#   both/DT
#   are/VBP
#   (VP believed/VBN)
#   to/TO
#   (VP have/VB)
#   (VP
#     (VP (VP tortured/VBN) and/CC (VP murdered/VBN))
#     (CIRC at/IN (NP least/JJS twelve/JJ young/JJ women/NNS))
#     (CIRC between/IN 1967/YEAR and/CC 1987/YEAR))
#   ,/,
#   1987/CD
#   many/JJ
#   at/IN
#   their/PRP$
#   (NP home/NN)
#   (CIRC in/IN (NE Gloucester/NNP))
#   ;/:
#   he/PRP
#   (VP
#     (VP (VP committed/VBD) (NP suicide/NN))
#     (CIRC in/IN 1995/YEAR)
#     (CIRC while/IN 1995/YEAR))
#   (VP (VP awaiting/VBG) (NP 1995/CD trial/NN))
#   ./.)
# Ada Williams:
# (S
#   (NE Ada/NNP Williams/NNP)
#   (/(
#   (VP (VP baby/VB) (NP farmer/NN))
#   )/)
#   (NE Ada/NNP Williams/NNP)
#   :/:
#   (NP 19th-century/JJ baby/NN farmer/NN)
#   who/WP
#   (VP
#     (VP (VP strangled/VBD) (NP an/DT infant/NN))
#     (CIRC in/IN (NE September/NNP)))
#   1899/CD
#   ;/:
#   (VP suspected/VBN)
#   of/OF
#   more/JJR
#   (NP murders/NNS)
#   ;/:
#   (VP executed/VBN)
#   1900/CD
#   ./.)
# Catherine Wilson:
# (S
#   (NE Catherine/NNP Wilson/NNP)
#   :/:
#   (NP nurse/NN)
#   (VP considered/VBN)
#   to/TO
#   (VP have/VB)
#   (VP
#     (VP (VP poisoned/VBN) (NP seven/CD people/NNS))
#     (CIRC in/IN (NP the/DT 19th/JJ century/NN)))
#   ;/:
#   (VP (VP executed/VBN) (CIRC in/IN 1862/YEAR))
#   ./.)
# Mary Elizabeth Wilson:
# (S
#   (NE Mary/NNP Elizabeth/NNP Wilson/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE (NE Merry/NNP Widow/NNP) of/OF (NE Windy/NNP Nook/NNP))
#   ''/''
#   ;/:
#   (VP convicted/VBN)
#   of/OF
#   (VP (VP murdering/VBG) (NP two/CD husbands/NNS))
#   by/IN
#   (VP (VP poisoning/VBG) and/CC (VP considered/VBN))
#   to/TO
#   (VP have/VB)
#   (VP (VP killed/VBN) (NP two/CD others/NNS))
#   ./.)
# Steve Wright:
# (S
#   (NE Steve/NNP Wright/NNP)
#   (/(
#   (NP serial/JJ killer/NN)
#   )/)
#   (NE Steve/NNP Wright/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE The/DT (NE Suffolk/NNP Strangler/NNP))
#   ''/''
#   ;/:
#   (NE (NE Ipswich/NNP) (NP 2006/CD serial/NN))
#   (VP
#     (VP (VP murderskilled/VBD) (NP five/CD women/NNS))
#     (CIRC in/IN (NP six/CD weeks/NNS))
#     (CIRC around/IN (NE Ipswich/NNP)))
#   in/IN
#   late/JJ
#   2006/CD
#   ;/:
#   (VP (VP sentenced/VBN) to/TO (NP life/NN imprisonment/NN))
#   ./.)
# Graham Young:
# (S
#   (NE Graham/NNP Young/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE The/DT (NE Teacup/NNP Poisoner/NNP))
#   ''/''
#   ;/:
#   (VP
#     (VP (VP killed/VBD) (NP three/CD people/NNS))
#     (CIRC from/IN 1962/YEAR to/TO 1971/YEAR))
#   ;/:
#   1971/YEAR
#   (VP died/VBN)
#   1971/YEAR
#   (CIRC in/IN (NP 1971/CD prison/NN))
#   (CIRC in/IN 1990/YEAR)
#   ./.)
# The Shankill Butchers:
# (S
#   (NP Shankill/JJ Butchers/NNS)
#   :/:
#   (NE The/DT (NE Shankill/NNP Butchers/NNP))
#   (VP
#     (VP was/VBD)
#     (NE (NE an/DT (NE Ulster/NNP)) (NP loyalist/NN gang—many/NN)))
#   of/OF
#   whom/WP
#   (VP (VP were/VBD) (NP members/NNS))
#   of/OF
#   (NE the/DT (NE Ulster/NNP Volunteer/NNP Force/NNP))
#   (/(
#   (NE UVF/NNP)
#   )/)
#   —that/WDT
#   (VP was/VBD)
#   active/JJ
#   (CIRC between/IN 1975/YEAR and/CC 1982/YEAR)
#   (CIRC in/IN 1982/CD)
#   (NE Belfast/NNP)
#   ,/,
#   (NE Northern/NNP Ireland/NNP)
#   ./.
#   (NP The/DT gang/NN)
#   (VP was/VBD)
#   (VP
#     (VP based/VBN)
#     (CIRC in/IN (NE (NE the/DT (NE Shankill/NNP)) (NP area/NN))))
#   and/CC
#   (VP were/VBD)
#   responsible/JJ
#   (CIRC for/IN (NP the/DT deaths/NNS))
#   of/OF
#   (CIRC at/IN (NP least/JJS twenty-three/JJ people/NNS))
#   ,/,
#   most/JJS
#   of/OF
#   whom/WP
#   (VP (VP were/VBD) (NE Irish/JJ (NE Catholics/NNPS)))
#   (VP (VP killed/VBN) (CIRC in/IN (NP sectarian/JJ attacks/NNS)))
#   ./.)
# Robert Black:
# (S
#   (NE Robert/NNP Black/NNP)
#   (/(
#   (NP serial/JJ killer/NN)
#   )/)
#   (NE Robert/NNP Black/NNP)
#   :/:
#   (NP schoolgirl/JJ killer/NN)
#   ;/:
#   (VP
#     (VP (VP convicted/VBN) of/OF (NP four/CD murders/NNS))
#     (CIRC in/IN (NE Northern/NNP Ireland/NNP)))
#   ,/,
#   (NE England/NNP)
#   ,/,
#   and/CC
#   (NE Scotland/NNP)
#   (CIRC between/IN 1981/YEAR and/CC 1986/YEAR)
#   ,/,
#   1986/YEAR
#   (VP suspected/VBD)
#   1986/YEAR
#   of/OF
#   1986/CD
#   many/JJ
#   more/JJR
#   ;/:
#   (VP
#     (VP died/VBN)
#     (CIRC in/IN (NP prison/NN))
#     (CIRC in/IN 2016/YEAR))
#   ./.)
# Burke:
# (S
#   (NE Burke/NNP)
#   and/CC
#   (NE Hare/NNP murdersWilliam/NNP Burke/NNP)
#   and/CC
#   (NE William/NNP Hare/NNP)
#   :/:
#   (NP notorious/JJ body/NN snatchers/NNS)
#   (CIRC in/IN (NE Edinburgh/NNP))
#   (CIRC in/IN (NP the/DT 19th/JJ century/NN))
#   ./.)
# Archibald Hall:
# (S
#   (NE Archibald/NNP Hall/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE Monster/NNP Butler/NNP)
#   ''/''
#   ;/:
#   (VP killed/VBN)
#   five/CD
#   in/IN
#   the/DT
#   1970s/CD
#   ,/,
#   three/CD
#   (CIRC with/IN (NP accomplice/NN))
#   (NE Michael/NNP Kitto/NNP)
#   ./.)
# Peter Manuel:
# (S
#   (NE Peter/NNP Manuel/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   the/DT
#   ``/``
#   (NE (NE Beast/NNP) of/OF (NE Birkenshaw/NNP))
#   ,/,
#   (NE North/NNP LanarkshireBirkenshaw/NNP)
#   ''/''
#   ;/:
#   (NE (NE American-born/NNP) (NP murderer/NN))
#   of/OF
#   seven/CD
#   ,/,
#   (VP suspected/VBN)
#   of/OF
#   (VP killing/VBG)
#   15/CD
#   ;/:
#   (VP (VP executed/VBN) (CIRC in/IN 1958/YEAR))
#   ./.)
# Edward William Pritchard:
# (S
#   (NE Edward/NNP William/NNP Pritchard/NNP)
#   :/:
#   (NP English/JJ doctor/NN)
#   who/WP
#   (VP poisoned/VBD)
#   his/PRP$
#   (NP wife/NN)
#   and/CC
#   her/PRP$
#   (NP mother/NN)
#   (CIRC in/IN (NE Glasgow/NNP))
#   (CIRC in/IN 1865/YEAR)
#   ;/:
#   (NP two/CD years/NNS)
#   earlier/RBR
#   their/PRP$
#   (NP maid/NN)
#   (VP had/VBD)
#   (VP (VP died/VBN) (CIRC in/IN (NP a/DT mysterious/JJ fire/NN)))
#   ./.)
# End MurdersAngus Sinclair:
# (S
#   (NP Worlds/NNS)
#   (NE End/NNP MurdersAngus/NNP Sinclair/NNP)
#   :/:
#   (VP
#     (VP convicted/VBN)
#     of/OF
#     (NP
#       (NP the/DT murders/NNS)
#       of/OF
#       (NP four/CD young/JJ women/NNS)))
#   ,/,
#   (VP including/VBG)
#   the/DT
#   ``/``
#   (NE (NE Worlds/NNP) (NP End/NN))
#   (NE Murders/NNPS)
#   ''/''
#   (CIRC in/IN (NE Edinburgh/NNP))
#   ,/,
#   (VP believed/VBD)
#   to/TO
#   (VP have/VB)
#   (VP murdered/VBN)
#   eight/CD
#   ;/:
#   (VP
#     (VP died/VBN)
#     (CIRC in/IN (NP prison/NN))
#     (CIRC in/IN 2019/YEAR))
#   ./.)
# Peter Tobin:
# (S
#   (NE Peter/NNP Tobin/NNP)
#   :/:
#   (NP
#     (NP (NP rapist/NN) and/CC (NP killer/NN))
#     of/OF
#     (NP three/CD women/NNS))
#   (CIRC in/IN (NE Scotland/NNP) and/CC (NE England/NNP))
#   (CIRC between/IN 1991/YEAR and/CC 2006/YEAR)
#   ;/:
#   2006/YEAR
#   (VP sentenced/VBN)
#   2006/YEAR
#   to/TO
#   (NP 2006/CD life/NN)
#   (CIRC in/IN (NP prison/NN))
#   ./.)
# John Cooper:
# (S
#   (NE John/NNP Cooper/NNP)
#   (/(
#   (NP serial/JJ killer/NN)
#   )/)
#   (NE John/NNP Cooper/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE The/DT (NE Wildman/NNP))
#   ''/''
#   and/CC
#   ``/``
#   (NE The/DT (NE Bullseye/NNP Killer/NNP))
#   ''/''
#   ;/:
#   (NE (NE Pembrokeshire/NNP) (NP burglar/NN))
#   responsible/JJ
#   (CIRC
#     for/IN
#     (NP
#       (NP
#         (NP the/DT robbery/NN)
#         and/CC
#         (NP shotgun/JJ double-murders/NNS))
#       of/OF
#       (NP (NP a/DT brother/NN) and/CC (NP sister/NN))))
#   (CIRC in/IN 1985/YEAR and/CC 1985/YEAR)
#   (NP a/DT (NP 1985/CD couple/NN))
#   (CIRC in/IN 1989/YEAR)
#   ./.)
# Peter Moore:
# (S
#   (NE Peter/NNP Moore/NNP)
#   (/(
#   (NP serial/JJ killer/NN)
#   )/)
#   (NE Peter/NNP Moore/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE The/DT (NE Man/NNP))
#   (CIRC in/IN (NE Black/NNP))
#   ''/''
#   ;/:
#   (NP businessman/NN)
#   who/WP
#   (VP
#     (VP (VP killed/VBD) (NP four/CD men/NNS))
#     (CIRC at/IN (NP random/NN))
#     (CIRC in/IN (NE North/NNP Wales/NNP))
#     (CIRC in/IN 1995/YEAR))
#   ./.)
# Pablo Goncálvez:
# (S
#   (NE Pablo/NNP Goncálvez/NNP)
#   :/:
#   (NP Spanish-born/JJ murderer/NN)
#   who/WP
#   (VP (VP killed/VBD) (NP tennis/NN player/NN))
#   (NE Patricia/NNP Miller/NNP)
#   (/(
#   (NP tennis/NN)
#   )/)
#   (NE
#     (NE Patricia/NNP Millers/NNP)
#     (NP (NP half-sister/NN) and/CC (NP two/CD other/JJ women/NNS)))
#   ;/:
#   (VP (VP freed/VBN) (CIRC in/IN 2016/YEAR but/CC 2016/YEAR))
#   (VP was/VBD)
#   2016/YEAR
#   (VP arrested/VBN)
#   2016/YEAR
#   (CIRC in/IN 2017/YEAR)
#   (CIRC in/IN 2017/CD)
#   (NE Paraguay/NNP)
#   for/IN
#   (VP
#     (VP carrying/VBG)
#     (NP
#       (NP
#         (NP an/DT unregistered/JJ weapon/NN)
#         and/CC
#         (NP a/DT quantity/NN))
#       of/OF
#       (NP cocaine/NN)))
#   ./.)
# Polatbay Berdaliyev:
# (S
#   (NE Polatbay/NNP Berdaliyev/NNP)
#   :/:
#   (VP raped/VBD)
#   ,/,
#   (VP
#     (VP
#       (VP (VP murdered/VBN) and/CC (VP robbed/VBN))
#       (NP (NP a/DT total/NN) of/OF (NP eleven/JJ women/NNS)))
#     (CIRC in/IN (NE Uzbekistan/NNP)))
#   and/CC
#   (VP
#     (VP (VP neighboring/VBG) (NE Kazakhstan/NNP))
#     (CIRC with/IN (NP accomplice/NN)))
#   (NE Abduseit/NNP Ormanov/NNP)
#   (CIRC between/IN 2011/YEAR and/CC 2012/YEAR)
#   ;/:
#   2012/YEAR
#   both/DT
#   2012/YEAR
#   (VP sentenced/VBN)
#   2012/YEAR
#   to/TO
#   (NP 2012/CD life/NN imprisonment/NN)
#   (CIRC in/IN (NP both/DT countries/NNS))
#   ./.)
# Dorángel Vargas:
# (S
#   (NE Dorángel/NNP Vargas/NNP)
#   :/:
#   (VP
#     (VP (VP killed/VBN) and/CC (VP cannibalized/VBN))
#     (CIRC at/IN (NP least/JJS ten/JJ men/NNS))
#     (CIRC between/IN 1997/YEAR and/CC 1999/YEAR)
#     (CIRC in/IN 1999/CD))
#   (NE San/NNP Cristóbal/NNP)
#   ,/,
#   (NE Táchira/NNP)
#   ./.)
# Yemeni reunion:
# (S
#   Abdallah/JJ
#   al-Hubal/JJ
#   :/:
#   (VP
#     (VP (VP killed/VBN) (NP seven/CD people/NNS))
#     (CIRC in/IN 1990/YEAR)
#     (CIRC after/IN 1990/YEAR))
#   the/DT
#   1990/CD
#   (NE (NE Yemeni/NNP) (NP reunion/NN))
#   ;/:
#   (VP (VP fled/VBN) (NP prison/NN))
#   and/CC
#   (VP
#     (VP
#       (VP killed/VBD)
#       (NP
#         (NP a/DT young/JJ couple/NN)
#         and/CC
#         (NP three/CD other/JJ people/NNS)))
#     (CIRC in/IN 1998/YEAR))
#   ;/:
#   1998/YEAR
#   (VP killed/VBN)
#   1998/YEAR
#   (CIRC in/IN 1998/YEAR)
#   (NP a/DT (NP 1998/CD shootout/NN))
#   (CIRC with/IN (NP the/DT police/NN))
#   ./.)
# Mohammed Adam Omar:
# (S
#   (NE Mohammed/NNP Adam/NNP Omar/NNP)
#   :/:
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE The/DT (NE Sanaa/NNP Ripper/NNP))
#   ''/''
#   ;/:
#   (NE (NE Sudanese/NNP) (NP morgue/NN assistant/NN))
#   who/WP
#   (VP
#     (VP killed/VBD)
#     (CIRC between/IN two/YEAR and/CC (NP 51/CD women/NNS))
#     (CIRC
#       across/IN
#       (NP (NP Yemen/NNS) and/CC (NP other/JJ countries/NNS)))
#     (CIRC from/IN 1975/YEAR to/TO 1999/YEAR))
#   ;/:
#   1999/YEAR
#   (VP guilt/VBN)
#   1999/YEAR
#   (VP has/VBZ)
#   1999/YEAR
#   (VP been/VBN)
#   1999/YEAR
#   (VP questioned/VBN)
#   1999/YEAR
#   ;/:
#   1999/YEAR
#   (VP executed/VBN)
#   2001/YEAR
#   ./.)
# Dhu Shanatir:
# (S
#   (NE Dhu/NNP Shanatir/NNP)
#   :/:
#   (NE 5th-century/JJ (NE Yemeni/NNP))
#   (/(
#   formerly/RB
#   (NE Himyarite/NNP)
#   )/)
#   (NP serial/JJ killer/NN)
#   ./.)
# Mailoni Brothers:
# (S
#   (NE (NE Mailoni/NNP) (NP Brothers/NNS))
#   :/:
#   (NP three/CD brothers/NNS)
#   who/WP
#   (VP
#     (VP killed/VBD)
#     (CIRC at/IN (NP least/JJS twelve/JJ people/NNS))
#     (CIRC from/IN 2007/YEAR to/TO 2013/YEAR)
#     (CIRC in/IN 2013/CD))
#   (NE Central/NNP Province/NNP)
#   ,/,
#   (NE ZambiaCentral/NNP Province/NNP)
#   ./.)
# Richard McGown:
# (S
#   (NE Richard/NNP McGown/NNP)
#   :/:
#   also/RB
#   (VP known/VBN)
#   as/IN
#   ``/``
#   (NE Dr./NNP Death/NNP)
#   ''/''
#   ;/:
#   (NE (NE Scottish/NNP) (NP doctor/NN))
#   responsible/JJ
#   for/IN
#   (VP
#     (VP administering/VBG)
#     (NP (NP fatal/JJ doses/NNS) of/OF (NP morphine/NN)))
#   to/TO
#   at/IN
#   least/JJS
#   (NP five/CD patients/NNS)
#   (CIRC in/IN (NE Harare/NNP))
#   (CIRC from/IN 1986/YEAR to/TO 1992/YEAR)
#   ;/:
#   1992/YEAR
#   (VP convicted/VBN)
#   1992/YEAR
#   of/OF
#   (NP (NP two/CD counts/NNS) of/OF (NP culpable/JJ homicide/NN))
#   and/CC
#   (VP
#     (VP (VP sentenced/VBN) to/TO (NP a/DT year/NN))
#     (CIRC in/IN (NP prison/NN)))
#   ,/,
#   after/IN
#   which/WDT
#   he/PRP
#   (VP was/VBD)
#   (VP
#     (VP (VP released/VBN) and/CC (VP returned/VBN))
#     to/TO
#     (NE the/DT (NE UK/NNP)))
#   ./.)
# B1 Butcher:
# (S
#   (NE B1/NNP Butcher/NNP)
#   :/:
#   (VP murdered/VBN)
#   at/IN
#   least/JJS
#   (NP five/CD women/NNS)
#   (CIRC between/IN 2005/YEAR and/CC 2007/YEAR)
#   ,/,
#   2007/YEAR
#   (CIRC with/IN 2007/YEAR)
#   (NP all/DT (NP 2007/CD murders/NNS))
#   (VP
#     (VP related/VBN)
#     to/TO
#     (NE (NE the/DT (NE B1/NNP)) (NP road/NN)))
#   (/(
#   (NE Namibia/NNP)
#   )/)
#   (NE National/NNP Road/NNP B1/NNP)
#   ./.)
# San Juan:
# (S
#   (NE San/NNP Juan/NNP)
#   del/FW
#   (NE Sur/NNP Psychopath/NNP)
#   :/:
#   (VP (VP murdered/VBN) (CIRC between/IN two/YEAR and/CC two/YEAR))
#   (VP
#     (VP (VP ten/VB) (NP two/CD men/NNS))
#     (CIRC in/IN (NP the/DT coastal/JJ town/NN)))
#   of/OF
#   (NE San/NNP Juan/NNP)
#   del/FW
#   (NE Sur/NNP)
#   ,/,
#   (CIRC from/IN 2000/YEAR to/TO 2002/YEAR)
#   ;/:
#   2002/YEAR
#   (NP a/DT (NP 2002/CD German/JJ alien/NN))
#   (/(
#   (NP law/NN)
#   )/)
#   (NP illegal/JJ alien/JJ residing/NN)
#   (CIRC in/IN (NE Managua/NNP))
#   (VP was/VBD)
#   (VP (VP arrested/VBN) (CIRC on/IN (NP suspicion/NN)))
#   ,/,
#   but/CC
#   later/RB
#   (VP (VP cleared/VBN) of/OF (NP the/DT murders/NNS))
#   ./.)

# %%
cases=copy_dict5

# %%
file={}
for country in cases :
    country_file={}
    for killer in cases[country]:
        killer_file={}
        murder_info=getMurderInfo(cases[country][killer])
        crime_time=''
        crime_place='in '+country+' '
        victims=''
        for m in murder_info:
            crime_time+=" , ".join(getTimes(m))
            crime_place+=" , ".join(getPlaces(m))
            victims+=" , ".join(getObject(m))
                
        killer_file['crime_time']=crime_time
        killer_file['crime_place']=crime_place
        killer_file['victims']=victims
        country_file[killer]=killer_file
    file[country]=country_file

# %%
for country in file:
    for killer in file[country]:
        print(killer+" murdered "+file[country][killer]['victims']+",PLACE "+file[country][killer]['crime_place']+" ,TIME "+file[country][killer]['crime_time'])
# Out:
# Abdullah Shah murdered least twenty travelers , the road,PLACE in Afghanistan from Kabul to Jalalabad ,TIME
# John Baughman murdered ,PLACE in Antigua and Barbuda  ,TIME
# Mailoni Brothers murdered least twelve people,PLACE in Zambia  ,TIME from 2007 to 2013
# Richard McGown murdered ,PLACE in Zimbabwe  ,TIME
# B1 Butcher murdered ,PLACE in Namibia  ,TIME
# San Juan murdered the murders,PLACE in Nicaragua  ,TIME between two and two

# %%
def pickALetter(letter):
    letter=letter.upper()
    for country in cases:
        for killer in cases[country]:
            goodFirstLetter=False
            tok_name=nltk.word_tokenize(killer)
            for word in tok_name:
                if word[0].upper()==letter:
                    goodFirstLetter=True
            if goodFirstLetter:
                print(killer+" murdered "+file[country][killer]['victims']+",PLACE "+file[country][killer]['crime_place']+" ,TIME "+file[country][killer]['crime_time'])

# %%
pickALetter('J')
# Out:
# John Baughman murdered ,PLACE  ,TIME
# John Balaban murdered ,PLACE  ,TIME
# John Bunting murdered murders of twelve people,PLACE  ,TIME between 1992 and 1999
# John Leslie Coombes murdered two men , one woman,PLACE  ,TIME in 1984 and one woman , in 2009 , around 2009
# John Wayne Glover murdered six elderly women,PLACE  ,TIME
# Matthew James Harris murdered a friends brother,PLACE  ,TIME
# Thomas Jeffries murdered 1826.Thomas Jeffries,PLACE  ,TIME
# John Lynch murdered ,PLACE  ,TIME
# John murdered ,PLACE  ,TIME in 1855
# Jack Unterweger murdered ten murders,PLACE  ,TIME
# Jan Caubergh murdered ,PLACE  ,TIME
# Ronald Janssen murdered a woman,PLACE  ,TIME in 2007 and 2007
# Marie-Thérèse Joniaux murdered ,PLACE  ,TIME
# José Augusto murdered Brazilian serial killermurdering,PLACE  ,TIME
# Marcelo de Jesus Silva murdered twenty counts of murder,PLACE  ,TIME
# José Paz Bezerra murdered ,PLACE  ,TIME
# Abraão José Bueno murdered four child patients,PLACE  ,TIME
# José Vicente Matias murdered ,PLACE  ,TIME
# Jorge Luiz Thais Martins murdered nine drug addictsthe death,PLACE  ,TIME from August
# John Martin Crawford murdered ,PLACE  ,TIME
# Russell Maurice Johnson murdered ,PLACE  ,TIME
# Gilbert Paul Jordan murdered eight women , alcohol poisoning,PLACE in Vancouver ,TIME between eight and eight
# Joseph LaPage murdered four women,PLACE in Canada and the US ,TIME from 1867 to 1875
# Julio Pérez Silva murdered fourteen women,PLACE  ,TIME from 1998 to 2001
# Zhang Jun murdered 28 people,PLACE  ,TIME from 1993 to 2000in 2001
# Jaime Iván Martínez murdered ,PLACE  ,TIME
# John Jairo Moreno murdered prison , several inmates , 1998. date28,PLACE  ,TIME
# Jaroslava Fabiánová murdered four men , 2003 financial reasons,PLACE  ,TIME between 1981 and 2003
# Jaroslav murdered eight pensioners,PLACE  ,TIME from 2001 to 2002
# Juan Fernando Hermosa murdered twenty-three people,PLACE  ,TIME from 1991 to 1992
# Johannes-Andreas Hanni murdered three people,PLACE  ,TIME in 1982
# Juhani Aataminpoika murdered death,PLACE  ,TIME
# Ismo Junni murdered four people , arson attacks , allotment garden,PLACE in Helsinki ,TIME from 1986 to 1989
# Jukka Lindholm murdered three women,PLACE  ,TIME from 1985 to 1993 , in 1993 and 1993
# Jacquy Haddouche murdered ,PLACE  ,TIME
# Hélène Jégado murdered least twenty-three people,PLACE  ,TIME between 1833 and 1851in 1852
# Joseph Vacher murdered guillotine,PLACE  ,TIME
# Jeanne Weber murdered the strangulation murders of ten children,PLACE  ,TIME
# M. Jaishankar murdered ,PLACE  ,TIME
# Chandrakant Jha murdered seven male migrants,PLACE  ,TIME from 1998 to 2007
# Ripper Jayanandan murdered seven people , robberies,PLACE  ,TIME
# Esmail Jafarzadeh murdered a young girl2017. date6,PLACE  ,TIME in 2017
# Japan murdered ,PLACE  ,TIME
# Juana Barraza murdered ,PLACE  ,TIME
# José Luis Calva murdered ,PLACE  ,TIME
# The Ciudad Juárez Rebels murdered women,PLACE  ,TIME from 1995 to 1996
# Luis Oscar Jiménez Herrera murdered sixteen women,PLACE  ,TIME between 2013 and 2016
# Jorge Humberto Martínez Córtez murdered ,PLACE  ,TIME between two and three
# Józef Cyppek murdered same yearother murders,PLACE  ,TIME that same year
# Joachim Knychała murdered five women,PLACE  ,TIME between 1975 and 1982
# Juraj Lupták murdered ,PLACE  ,TIME
# Jozef Slovák murdered ,PLACE  ,TIME
# Jimmy Maketta murdered sixteen counts of murder,PLACE  ,TIME
# Jack Mogale murdered ,PLACE  ,TIME
# Joaquín Ferrándiz Ventura murdered five women,PLACE  ,TIME between 1995 and 1996
# Juan Díaz de Garayo murdered six peoplegarrote,PLACE  ,TIME from 1870 to 1879in 1881
# José Antonio Rodríguez Vega murdered least sixteen elderly women,PLACE  ,TIME
# John Ingvar Lövgren murdered four murders,PLACE  ,TIME
# Bible John murdered ,PLACE  ,TIME
# Jack murdered ,PLACE  ,TIME
# John Childs murdered ,PLACE  ,TIME
# John Christie murdered ,PLACE  ,TIME
# John Duffy murdered three women , railway stations,PLACE  ,TIME
# John Haigh murdered six murders,PLACE  ,TIME
# Theodore Johnson murdered ,PLACE  ,TIME
# George Joseph Smith murdered three women,PLACE  ,TIME
# John Straffen murdered three children,PLACE  ,TIME between 1951 and 1952
# John Cooper murdered ,PLACE  ,TIME
# San Juan murdered the murders,PLACE  ,TIME between two and two

# %%
print(cases['Antigua and Barbuda']['John Baughman'])
# Out:
# (S
#   (NE John/NNP Baughman/NNP)
#   :/:
#   (NP former/JJ American/JJ police/NN officer/NN)
#   who/WP
#   (VP pushed/VBD)
#   his/PRP$
#   (NP second/JJ wife/NN)
#   (CIRC from/IN (NP the/DT roof/NN))
#   of/OF
#   (NE the/DT (NE Royal/NNP Antiguan/NNP Hotel/NNP))
#   (CIRC in/IN 1995/YEAR)
#   ;/:
#   1995/YEAR
#   (VP suspected/VBN)
#   1995/YEAR
#   of/OF
#   1995/YEAR
#   (VP killing/VBG)
#   1995/YEAR
#   (NP
#     (NP a/DT (NP 1995/CD close/JJ friend/NN))
#     and/CC
#     (NP first/JJ wife/NN))
#   back/RB
#   (CIRC in/IN (NE the/DT (NE USA/NNP)))
#   ;/:
#   (VP (VP (VP committed/VBD) (NP suicide/NN)) (CIRC in/IN 2000/YEAR))
#   ./.)
